# %% [markdown]
# ## Bin filtering and normalization

# %% [markdown]
# __running time__: < 10 min
#
# Columns in the matrix with significantly less interaction counts than the rest are likely to be genomic regions with low mappability or high repeat content like telomeres and centromeres. The consideration of those columns affect the performance and accuracy of most normalization algorithms. It is therefore necessary to discard those columns prior to the normalization of the matrix.
#
# `tadbit normalize` performs a bin filtering before the normalization.

# %% [markdown]
# ### Filter bins with low interaction counts
#
# #### Genome-wide filtering

# %% [markdown]
# In `tadbit normalize` the default measures to consider if a column should be filtered out are first the minimum sum of interactions in the column and second the ratio of cis/trans interactions. Artifactual columns with a sum below the defined threshold or a ratio of cis/trans interactions below the estimated minimum percentage are discarded.
#
# ![Bin filtering](images/filtering_summary_plot_10kb.png)

# %% [markdown]
# #### Threshold filtering
#
# In cases where the default methodology cannot be applied (for instance in sparse datasets or when we only have one chromosome) we can use thresholds with absolute values (`--min_count`) or percentages (`--perc_zeros`,`--min_perc`,`--max_perc`).

# %% [markdown]
# ### Normalization algorithms

# %% [markdown]
# *__Note__: if columns with a lot of zeroes are present the ICE normalization will last very long to converge, and these low-coverage columns will present, at the end of the normalization, few cells with very high values of interaction*

# %% [markdown]
# ### Iterative Correction and Eigenvector decomposition (ICE)

# %% [markdown]
# ICE normalization <a name="ref-1"/>[(Imakaev et al., 2012)](#cite-Imakaev2012a) assumes an equal experimental visibility of each bin and seeks iteratively for biases that equalize the sum of counts per bin in the matrix. At each iteration, a new matrix is generated by dividing each cell by the product of the sum of counts in its row times the sum of counts in its column. The process converges to a matrix in which all bins have identical sum.
#
# If $W$ is the raw matrix, $N$ is its size, and $i$($j$) the index of the columns(rows), the normalized matrix $M$ is iteratively computed as:
#
# $$M_{i,j} = \frac{W_{i,j}}{\sqrt{\sum_{n=0}^N{W_{i,n}} \times \sum_{n=0}^N{W_{n,j}}}}$$
#
# This normalization has usually a quite strong effect, and visually the matrices look very smooth and regular.

# %%
# %%bash
#
# tadbit normalize -w ../results/PSC_rep1/ --normalization ICE \
#     --resolution 10000 --min_count 100
# Out:
#   - Parsing BAM (101 chunks)                                                   [2022-11-19 12:38:44]
#       -> cis interactions are defined as being bellow 1 Mb
#       -> trans interactions are defined as being bellow 5 Mb
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Collecting cis and total interactions per bin (101 chunks)                 [2022-11-19 12:39:12]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .
#   - Removing columns with too few or too much interactions                     [2022-11-19 12:39:13]
#       -> too few interactions defined as less than       100 interactions
#       -> removed 346 columns (330/346 null/high counts) of 15975 (2.2%)
#   - Rescaling sum of interactions per bins                                     [2022-11-19 12:39:14]
#   - ICE normalization                                                          [2022-11-19 12:39:14]
#
#   (Matrix size 15975x15975)                                                    [2022-11-19 12:39:14]
#
#   - Parsing BAM (101 chunks)                                                   [2022-11-19 12:39:14]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Getting matrices                                                           [2022-11-19 12:39:20]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
# iterative correction
#   - copying matrix
#   - computing biases
#            132.000        2850.106       23322.000    0   7.18285
#           1922.541        2891.517        4174.870    1   0.44383
#           2566.874        2904.138        3346.273    2   0.15224
#           2600.137        2910.028        3130.806    3   0.10649
#           2771.900        2913.048        3186.070    4   0.09372
#           2710.838        2914.686        3014.893    5   0.06994
#           2846.801        2915.596        3089.517    6   0.05965
#           2782.927        2916.119        2965.081    7   0.04567
#           2882.000        2916.423        3028.812    8   0.03854
#           2828.587        2916.603        2941.203    9   0.03018
#           2898.710        2916.711        2989.636   10   0.02500
#           2859.220        2916.776        2930.239   11   0.01973
#           2906.718        2916.815        2964.008   12   0.01618
#           2879.392        2916.839        2924.458   13   0.01284
#           2911.082        2916.854        2947.275   14   0.01043
#           2892.676        2916.863        2921.258   15   0.00829
#           2913.508        2916.869        2936.392   16   0.00669
#           2901.333        2916.873        2919.526   17   0.00533
#           2914.730        2916.875        2929.381   18   0.00429
#           2906.899        2916.876        2918.611   19   0.00342
#           2915.475        2916.877        2924.882   20   0.00274
#           2910.495        2916.878        2918.012   21   0.00219
#           2915.960        2916.878        2921.984   22   0.00175
#           2912.809        2916.878        2917.621   23   0.00139
#           2916.277        2916.878        2920.128   24   0.00111
#           2914.291        2916.878        2917.366   25   0.00089
#           2916.484        2916.878        2918.942   26   0.00071
#           2915.236        2916.878        2917.199   27   0.00056
#           2916.619        2916.879        2918.187   28   0.00045
#           2915.837        2916.879        2917.089   29   0.00036
#           2916.707        2916.879        2917.708   30   0.00028
#           2916.219        2916.879        2917.018   31   0.00023
#           2916.765        2916.879        2917.403   32   0.00018
#           2916.461        2916.879        2916.971   33   0.00014
#           2916.803        2916.879        2917.211   34   0.00011
#           2916.615        2916.879        2916.940   35   0.00009
#           2916.828        2916.879        2917.089   36   0.00007
#           2916.712        2916.879        2916.919   37   0.00006
#           2916.845        2916.879        2917.011   38   0.00005
#           2916.773        2916.879        2916.906   39   0.00004
#           2916.856        2916.879        2916.962   40   0.00003
#           2916.812        2916.879        2916.897   41   0.00002
#           2916.864        2916.879        2916.932   42   0.00002
#           2916.836        2916.879        2916.891   43   0.00001
#           2916.868        2916.879        2916.912   44   0.00001
#           2916.852        2916.879        2916.887   45   0.00001
#           2916.872        2916.879        2916.900   46   0.00001
#           2916.862        2916.879        2916.884   47   0.00001
#           2916.874        2916.879        2916.892   48   0.00000
#           2916.868        2916.879        2916.882   49   0.00000
#           2916.875        2916.879        2916.887   50   0.00000
#           2916.872        2916.879        2916.881   51   0.00000
#           2916.876        2916.879        2916.884   52   0.00000
#           2916.874        2916.879        2916.880   53   0.00000
#           2916.877        2916.879        2916.882   54   0.00000
#           2916.876        2916.879        2916.880   55   0.00000
# rescaling to factor 1
#   - getting the sum of the matrix
#     => 15629.000
#   - rescaling biases
#   - Getting sum of normalized bins                                             [2022-11-19 12:43:09]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing Cis percentage                                                   [2022-11-19 12:43:11]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#     * Cis-percentage: 100.0%
#   - Rescaling decay                                                            [2022-11-19 12:43:14]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing interaction decay vs genomic distance                            [2022-11-19 12:43:20]
#     -> Decay slope 0.7-10 Mb	-1.155024667618345
#   - Saving biases and badcol columns                                           [2022-11-19 12:43:21]
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.--------------.
# | Id | JOBid |                                                                           Path |         Type |
# |----+-------+--------------------------------------------------------------------------------+--------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |      WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz | MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |        INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |       FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |      SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |      SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz | MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |       FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |      SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |      SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz | MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |       FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |      SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |      SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz | MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |       FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |      SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |      SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |          BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |        FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |          BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |      HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |      HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |       FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |       FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |       FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |       FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |       FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |       FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |       FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |       FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |       FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |       FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |       FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |       BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |       FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |          TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |   RAW_FIGURE |
# | 46 |    12 |                                 04_normalization/biases_10kb_91cf12b651.pickle |       BIASES |
# | 47 |    12 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |       FIGURE |
# '----^-------^--------------------------------------------------------------------------------^--------------'
# ,------.
# | JOBs |
# ,----.--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                       Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                   skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                    skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                    skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                    skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                      type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                              force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                           reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:24:57 | 15/11/2022 22:25:06 | Normalize |     dd4e283c12 |
# | 10 |                                                                                     nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:54:53 | 15/11/2022 23:01:14 |   Segment |     78ca8c83b1 |
# | 11 | nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 23:02:16 | 15/11/2022 23:02:17 |       Bin |     917a355190 |
# | 12 |                                                                                                                reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 19/11/2022 12:38:44 | 19/11/2022 12:43:21 | Normalize |     91cf12b651 |
# '----^--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,----------------------.
# | INTERSECTION_OUTPUTs |
# ,----.--------.--------------------.-----------------------.------------------------.---------------------.---------------------.
# | Id | PATHid | Total_interactions | Multiple_interactions | Median_fragment_length | MAD_fragment_length | Max_fragment_length |
# |----+--------+--------------------+-----------------------+------------------------+---------------------+---------------------|
# |  1 |     22 |         33,026,529 |   2:793590 3:2649 4:4 |                    144 |                  55 |                 624 |
# '----^--------^--------------------^-----------------------^------------------------^---------------------^---------------------'
# ,---------------.
# | MAPPED_INPUTs |
# ,----.--------.-------------.------.------.------.--------.---------------.-------------------.----------.-----------------.---------.
# | Id | PATHid |     Entries | Trim | Frag | Read | Enzyme | Dangling_Ends |    Ligation_Sites | WRKDIRid | MAPPED_OUTPUTid | INDEXid |
# |----+--------+-------------+------+------+------+--------+---------------+-------------------+----------+-----------------+---------|
# |  1 |      2 | 363,126,824 | None | full |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               5 |       3 |
# |  2 |      2 | 336,797,085 | None | frag |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               6 |       3 |
# |  3 |      7 | 307,207,567 | None | full |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |               9 |       3 |
# |  4 |      7 | 284,470,795 | None | frag |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |              10 |       3 |
# |  5 |     11 | 307,207,567 | None | full |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              13 |       3 |
# |  6 |     11 | 284,907,570 | None | frag |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              14 |       3 |
# |  7 |     15 | 363,126,824 | None | full |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              17 |       3 |
# |  8 |     15 | 337,015,337 | None | frag |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              18 |       3 |
# '----^--------^-------------^------^------^------^--------^---------------^-------------------^----------^-----------------^---------'
# ,----------------.
# | MAPPED_OUTPUTs |
# ,----.--------.-------.-----------------.
# | Id | PATHid | BEDid | Uniquely_mapped |
# |----+--------+-------+-----------------|
# |  1 |      6 |    19 |       6,487,780 |
# |  2 |      5 |    19 |      26,329,739 |
# |  3 |     10 |    19 |       4,095,047 |
# |  4 |      9 |    19 |      22,736,772 |
# |  5 |     14 |    21 |       4,327,299 |
# |  6 |     13 |    21 |      22,299,997 |
# |  7 |     18 |    21 |       6,473,705 |
# |  8 |     17 |    21 |      26,111,487 |
# '----^--------^-------^-----------------'
# ,----------------.
# | PARSED_OUTPUTs |
# ,----.--------.-----------------------.----------------.
# | Id | PATHid | Total_uniquely_mapped |      Multiples |
# |----+--------+-----------------------+----------------|
# |  1 |     19 |            59,649,338 | 1:1195164,2:60 |
# |  2 |     21 |            59,212,488 | 1:1212999,2:68 |
# '----^--------^-----------------------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  1 |     7 |    23 |     1,598 |         31 |        879 |         102.018229 |               100.0 |        -1.151699 |    100,000 |       Vanilla |      1 |
# |  2 |    12 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.155025 |     10,000 |           ICE |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %% [markdown]
# The resulting biases are stored in a pickle file under the subfolder `04_normalization` and are only valid for matrices binned at 50kbp resolution. Together with the biases file, `tadbit normalize` produces a plot of the relation between the genomic distance of two regions of the genome and the number of read pairs (interaction counts) having sequences mapped on to those two regions on each end:

# %%
# %%bash
#
# ls ../results/PSC_rep1/04_normalization/
# Out:
# biases_10kb_91cf12b651.pickle
# filtering_summary_plot_10kb_91cf12b651.png
# interactions_vs_genomic-coords.png_10000_91cf12b651.png

# %%
from IPython.display import Image
Image(filename='../results/PSC_rep1/04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png')

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm raw norm
# Out:
# Extraction of chr3:33950000-35450000
# Getting raw matrices                                                           [2022-11-15 21:58:41]
#
#   (Matrix size 150x150)                                                        [2022-11-15 21:58:41]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-15 21:58:42]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-15 21:58:42]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: raw                                                               [2022-11-15 21:58:42]
# Getting norm matrices                                                          [2022-11-15 21:58:43]
#
#   (Matrix size 150x150)                                                        [2022-11-15 21:58:43]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-15 21:58:43]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-15 21:58:43]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: norm                                                              [2022-11-15 21:58:44]
# Cleaning                                                                       [2022-11-15 21:58:45]
# Saving to DB                                                                   [2022-11-15 21:58:45]
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                  Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                              skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                               skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                               skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                               skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                 type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                         force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                           reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 | nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.--------------.
# | Id | JOBid |                                                                           Path |         Type |
# |----+-------+--------------------------------------------------------------------------------+--------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |      WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz | MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |        INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |       FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |      SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |      SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz | MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |       FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |      SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |      SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz | MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |       FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |      SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |      SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz | MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |       FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |      SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |      SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |          BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |        FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |          BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |      HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |      HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |       FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |       FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |       FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |       FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |       FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |       FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |       FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |       FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |       FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |       FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |       FILTER |
# | 37 |     7 |                                 04_normalization/biases_10kb_91cf12b651.pickle |       BIASES |
# | 38 |     7 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |       FIGURE |
# | 39 |     8 |                         05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png |   RAW_FIGURE |
# | 40 |     8 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png |   NRM_FIGURE |
# '----^-------^--------------------------------------------------------------------------------^--------------'

# %% [markdown]
# Raw matrix 10kb

# %%
Image(filename='../results_new/PSC_rep1/05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png')

# %% [markdown]
# ICE normalized matrix 10kb

# %%
Image(filename='../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png')

# %% [markdown]
# ### Vanilla coverage normalization

# %% [markdown]
# The vanilla normalization <a name="ref-2"/>[(Rao et al., 2014)](#cite-Rao2014) is a variation of the ICE where a single iteration is performed.

# %%
# %%bash
#
# tadbit normalize -w ../results/PSC_rep1/ --normalization Vanilla \
#     --resolution 10000 --min_count 100
# Out:
#   - Parsing BAM (101 chunks)                                                   [2022-11-15 22:00:46]
#       -> cis interactions are defined as being bellow 1 Mb
#       -> trans interactions are defined as being bellow 5 Mb
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Collecting cis and total interactions per bin (101 chunks)                 [2022-11-15 22:00:53]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .
#   - Removing columns with too few or too much interactions                     [2022-11-15 22:00:54]
#       -> too few interactions defined as less than       100 interactions
#       -> removed 346 columns (330/346 null/high counts) of 15975 (2.2%)
#   - Rescaling sum of interactions per bins                                     [2022-11-15 22:00:54]
#   - Vanilla normalization                                                      [2022-11-15 22:00:54]
#   - Getting sum of normalized bins                                             [2022-11-15 22:00:54]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing Cis percentage                                                   [2022-11-15 22:00:57]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#     * Cis-percentage: 100.0%
#   - Rescaling decay                                                            [2022-11-15 22:01:01]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing interaction decay vs genomic distance                            [2022-11-15 22:01:06]
#     -> Decay slope 0.7-10 Mb	-1.163010612104209
#   - Saving biases and badcol columns                                           [2022-11-15 22:01:06]
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.--------------.
# | Id | JOBid |                                                                           Path |         Type |
# |----+-------+--------------------------------------------------------------------------------+--------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |      WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz | MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |        INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |       FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |      SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |      SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz | MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |       FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |      SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |      SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz | MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |       FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |      SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |      SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz | MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |       FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |      SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |      SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |          BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |        FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |          BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |      HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |      HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |       FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |       FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |       FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |       FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |       FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |       FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |       FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |       FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |       FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |       FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |       FILTER |
# | 37 |     7 |                                 04_normalization/biases_10kb_91cf12b651.pickle |       BIASES |
# | 38 |     7 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |       FIGURE |
# | 39 |     8 |                         05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png |   RAW_FIGURE |
# | 40 |     8 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png |   NRM_FIGURE |
# | 41 |     9 |                                 04_normalization/biases_10kb_446ec599e6.pickle |       BIASES |
# | 42 |     9 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |       FIGURE |
# '----^-------^--------------------------------------------------------------------------------^--------------'
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                  Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                              skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                               skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                               skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                               skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                 type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                         force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                           reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 | nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# |  9 |                                                                                                       reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:00:46 | 15/11/2022 22:01:06 | Normalize |     446ec599e6 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,----------------------.
# | INTERSECTION_OUTPUTs |
# ,----.--------.--------------------.-----------------------.------------------------.---------------------.---------------------.
# | Id | PATHid | Total_interactions | Multiple_interactions | Median_fragment_length | MAD_fragment_length | Max_fragment_length |
# |----+--------+--------------------+-----------------------+------------------------+---------------------+---------------------|
# |  1 |     22 |         33,026,529 |   2:793590 3:2649 4:4 |                    144 |                  55 |                 624 |
# '----^--------^--------------------^-----------------------^------------------------^---------------------^---------------------'
# ,---------------.
# | MAPPED_INPUTs |
# ,----.--------.-------------.------.------.------.--------.---------------.-------------------.----------.-----------------.---------.
# | Id | PATHid |     Entries | Trim | Frag | Read | Enzyme | Dangling_Ends |    Ligation_Sites | WRKDIRid | MAPPED_OUTPUTid | INDEXid |
# |----+--------+-------------+------+------+------+--------+---------------+-------------------+----------+-----------------+---------|
# |  1 |      2 | 363,126,824 | None | full |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               5 |       3 |
# |  2 |      2 | 336,797,085 | None | frag |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               6 |       3 |
# |  3 |      7 | 307,207,567 | None | full |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |               9 |       3 |
# |  4 |      7 | 284,470,795 | None | frag |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |              10 |       3 |
# |  5 |     11 | 307,207,567 | None | full |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              13 |       3 |
# |  6 |     11 | 284,907,570 | None | frag |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              14 |       3 |
# |  7 |     15 | 363,126,824 | None | full |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              17 |       3 |
# |  8 |     15 | 337,015,337 | None | frag |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              18 |       3 |
# '----^--------^-------------^------^------^------^--------^---------------^-------------------^----------^-----------------^---------'
# ,----------------.
# | MAPPED_OUTPUTs |
# ,----.--------.-------.-----------------.
# | Id | PATHid | BEDid | Uniquely_mapped |
# |----+--------+-------+-----------------|
# |  1 |      6 |    19 |       6,487,780 |
# |  2 |      5 |    19 |      26,329,739 |
# |  3 |     10 |    19 |       4,095,047 |
# |  4 |      9 |    19 |      22,736,772 |
# |  5 |     14 |    21 |       4,327,299 |
# |  6 |     13 |    21 |      22,299,997 |
# |  7 |     18 |    21 |       6,473,705 |
# |  8 |     17 |    21 |      26,111,487 |
# '----^--------^-------^-----------------'
# ,----------------.
# | PARSED_OUTPUTs |
# ,----.--------.-----------------------.----------------.
# | Id | PATHid | Total_uniquely_mapped |      Multiples |
# |----+--------+-----------------------+----------------|
# |  1 |     19 |            59,649,338 | 1:1195164,2:60 |
# |  2 |     21 |            59,212,488 | 1:1212999,2:68 |
# '----^--------^-----------------------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  1 |     7 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.155025 |     10,000 |           ICE |      1 |
# |  2 |     9 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.163011 |     10,000 |       Vanilla |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm norm \
#     --jobid 9
# Out:
# Extraction of chr3:33950000-35450000
# Getting norm matrices                                                          [2022-11-15 22:04:14]
#
#   (Matrix size 150x150)                                                        [2022-11-15 22:04:14]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-15 22:04:14]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-15 22:04:15]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: norm                                                              [2022-11-15 22:04:15]
# Cleaning                                                                       [2022-11-15 22:04:16]
# Saving to DB                                                                   [2022-11-15 22:04:16]
# ,------.
# | JOBs |
# ,----.------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                     Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                 skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                  skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                  skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                  skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                    type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                            force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 |    nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# |  9 |                                                                                                          reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:00:46 | 15/11/2022 22:01:06 | Normalize |     446ec599e6 |
# | 10 | nox:0 reso:10000 jobid:7 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:01:09 | 15/11/2022 22:01:10 |       Bin |     dbd6039670 |
# | 11 |                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:SQRT factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:02:56 | 15/11/2022 22:03:16 | Normalize |     8fe261c68a |
# | 12 | nox:0 reso:10000 jobid:9 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:04:14 | 15/11/2022 22:04:16 |       Bin |     e89b5aa69f |
# '----^------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.--------------.
# | Id | JOBid |                                                                           Path |         Type |
# |----+-------+--------------------------------------------------------------------------------+--------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |      WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz | MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |        INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |       FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |      SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |      SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz | MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |       FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |      SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |      SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz | MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |       FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |      SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |      SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz | MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |       FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |      SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |      SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |          BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |        FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |          BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |      HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |      HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |       FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |       FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |       FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |       FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |       FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |       FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |       FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |       FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |       FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |       FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |       FILTER |
# | 37 |     7 |                                 04_normalization/biases_10kb_91cf12b651.pickle |       BIASES |
# | 38 |     7 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |       FIGURE |
# | 39 |     8 |                         05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png |   RAW_FIGURE |
# | 40 |     8 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png |   NRM_FIGURE |
# | 41 |     9 |                                 04_normalization/biases_10kb_446ec599e6.pickle |       BIASES |
# | 42 |     9 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |       FIGURE |
# | 43 |    10 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_dbd6039670.png |   NRM_FIGURE |
# | 44 |    11 |                                 04_normalization/biases_10kb_8fe261c68a.pickle |       BIASES |
# | 45 |    11 |       04_normalization/interactions_vs_genomic-coords.png_10000_8fe261c68a.png |       FIGURE |
# | 46 |    12 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_e89b5aa69f.png |   NRM_FIGURE |
# '----^-------^--------------------------------------------------------------------------------^--------------'

# %% [markdown]
# Vanilla normalized matrix 10kb

# %%
Image(filename='../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_e89b5aa69f.png')

# %% [markdown]
# ### Square root vanilla coverage (SQRT) normalization

# %% [markdown]
# The SQRT vanilla normalization <a name="ref-2"/>[(Rao et al., 2014)](#cite-Rao2014) is a variation of the Vanilla coverage where each element in the matrix is divided by the square root of the product of sums of counts.
#
# $$M_{i,j} = \frac{W_{i,j}}{\sqrt{\sum_{n=0}^N{W_{i,n}} \times \sum_{n=0}^N{W_{n,j}}}}$$

# %%
# %%bash
#
# tadbit normalize -w ../results/PSC_rep1/ --normalization SQRT \
#     --resolution 10000 --min_count 100
# Out:
# ,------.
# | JOBs |
# ,----.------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                     Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                 skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                  skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                  skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                  skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                    type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                            force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 |    nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# |  9 |                                                                                                          reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:00:46 | 15/11/2022 22:01:06 | Normalize |     446ec599e6 |
# | 10 | nox:0 reso:10000 jobid:7 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:01:09 | 15/11/2022 22:01:10 |       Bin |     dbd6039670 |
# | 11 |                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:SQRT factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:02:56 | 15/11/2022 22:03:16 | Normalize |     8fe261c68a |
# | 12 | nox:0 reso:10000 jobid:9 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:04:14 | 15/11/2022 22:04:16 |       Bin |     e89b5aa69f |
# '----^------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# WARNING: exact same job already computed, see JOBs table above
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_3840/2917930264.py in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\ntadbit normalize -w ../results_new/PSC_rep1/ --normalization SQRT \\\n    --resolution 10000 --min_count 100\n')
#
# ~/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2470             with self.builtin_trap:
#    2471                 args = (magic_arg_s, cell)
# -> 2472                 result = fn(*args, **kwargs)
#    2473             return result
#    2474
#
# ~/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# ~/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\ntadbit normalize -w ../results_new/PSC_rep1/ --normalization SQRT \\\n    --resolution 10000 --min_count 100\n'' returned non-zero exit status 1.

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm norm \
#     --jobid 11
# Out:
# Extraction of chr3:33950000-35450000
# Getting norm matrices                                                          [2022-11-15 22:07:24]
#
#   (Matrix size 150x150)                                                        [2022-11-15 22:07:24]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-15 22:07:24]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-15 22:07:25]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: norm                                                              [2022-11-15 22:07:25]
# Cleaning                                                                       [2022-11-15 22:07:26]
# Saving to DB                                                                   [2022-11-15 22:07:26]
# ,------.
# | JOBs |
# ,----.-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                      Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                  skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                   skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                   skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                   skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                     type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                             force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                               reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 |     nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# |  9 |                                                                                                           reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:00:46 | 15/11/2022 22:01:06 | Normalize |     446ec599e6 |
# | 10 |  nox:0 reso:10000 jobid:7 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:01:09 | 15/11/2022 22:01:10 |       Bin |     dbd6039670 |
# | 11 |                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:SQRT factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:02:56 | 15/11/2022 22:03:16 | Normalize |     8fe261c68a |
# | 12 |  nox:0 reso:10000 jobid:9 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:04:14 | 15/11/2022 22:04:16 |       Bin |     e89b5aa69f |
# | 13 | nox:0 reso:10000 jobid:11 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:07:24 | 15/11/2022 22:07:26 |       Bin |     c8e49087d1 |
# '----^-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.--------------.
# | Id | JOBid |                                                                           Path |         Type |
# |----+-------+--------------------------------------------------------------------------------+--------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |      WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz | MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |        INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |       FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |      SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |      SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz | MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |       FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |      SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |      SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz | MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |       FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |      SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |      SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz | MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |       FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |      SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |      SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |          BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |        FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |          BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |      HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |      HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |       2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |       FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |       FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |       FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |       FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |       FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |       FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |       FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |       FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |       FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |       FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |       FILTER |
# | 37 |     7 |                                 04_normalization/biases_10kb_91cf12b651.pickle |       BIASES |
# | 38 |     7 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |       FIGURE |
# | 39 |     8 |                         05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png |   RAW_FIGURE |
# | 40 |     8 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png |   NRM_FIGURE |
# | 41 |     9 |                                 04_normalization/biases_10kb_446ec599e6.pickle |       BIASES |
# | 42 |     9 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |       FIGURE |
# | 43 |    10 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_dbd6039670.png |   NRM_FIGURE |
# | 44 |    11 |                                 04_normalization/biases_10kb_8fe261c68a.pickle |       BIASES |
# | 45 |    11 |       04_normalization/interactions_vs_genomic-coords.png_10000_8fe261c68a.png |       FIGURE |
# | 46 |    12 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_e89b5aa69f.png |   NRM_FIGURE |
# | 47 |    13 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_c8e49087d1.png |   NRM_FIGURE |
# '----^-------^--------------------------------------------------------------------------------^--------------'

# %% [markdown]
# SQRT normalized matrix 10kb

# %%
Image(filename='../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_c8e49087d1.png')

# %% [markdown]
# ### OneD normalization

# %% [markdown]
# OneD normalization <a name="ref-3"/>[(Vidal et al., 2018)](#cite-Vidal2018) is based on fitting a non-linear model between the total amount of contacts per bin and the known biases:
#  - GC content
#  - number of RE sites (the most important bias, the more cut sites, the more mapped reads)
#  - read mappability (can be produced with genmap https://github.com/cpockrandt/genmap)
#
# As the estimation of each of this statistics is very important for the normalization, they are left outside the normalization function, in order to allow user to modify them.

# %%
# %%bash
#
# tadbit normalize -w ../results/PSC_rep1/ --normalization oneD \
#     --resolution 10000 --min_count 100 \
#     --fasta ../refGenome/mm39_chr3.fa \
#     --renz MboI \
#     --mappability ../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph
# Out:
#   - parsing FASTA                                                              [2022-11-15 22:08:12]
#   - Parsing mappability                                                        [2022-11-15 22:08:13]
#   - Computing GC content per bin (removing Ns)                                 [2022-11-15 22:08:13]
#   - Computing number of RE sites per bin (+/- 200 bp)                          [2022-11-15 22:08:14]
#   - Parsing BAM (101 chunks)                                                   [2022-11-15 22:08:15]
#       -> cis interactions are defined as being bellow 1 Mb
#       -> trans interactions are defined as being bellow 5 Mb
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Collecting cis and total interactions per bin (101 chunks)                 [2022-11-15 22:08:21]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .[1] "tot ~ s(map) + s(cg) + s(res)"
#
#   - Removing columns with too few or too much interactions                     [2022-11-15 22:08:22]
#       -> too few interactions defined as less than       100 interactions
#       -> removed 346 columns (330/346 null/high counts) of 15975 (2.2%)
#   - Rescaling sum of interactions per bins                                     [2022-11-15 22:08:23]
#   - oneD normalization                                                         [2022-11-15 22:08:23]
# ['Rscript', '--vanilla', '/home/dcastillo/miniconda2/envs/3DAROC22/bin/normalize_oneD.R', '../results_new/PSC_rep1/04_normalization/tmp_oneD_20256baab7/tot.csv', '../results_new/PSC_rep1/04_normalization/tmp_oneD_20256baab7/biases.csv', '"tot ~ s(map) + s(cg) + s(res)"']
#
#   - Getting sum of normalized bins                                             [2022-11-15 22:08:37]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing Cis percentage                                                   [2022-11-15 22:08:41]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#     * Cis-percentage: 100.0%
#   - Rescaling decay                                                            [2022-11-15 22:08:44]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing interaction decay vs genomic distance                            [2022-11-15 22:08:49]
#     -> Decay slope 0.7-10 Mb	-1.1440828463488184
#   - Saving biases and badcol columns                                           [2022-11-15 22:08:50]
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |         SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                 04_normalization/biases_10kb_91cf12b651.pickle |          BIASES |
# | 38 |     7 |       04_normalization/interactions_vs_genomic-coords.png_10000_91cf12b651.png |          FIGURE |
# | 39 |     8 |                         05_sub-matrices/raw_chr3:3395-3545_10kb_bab7be0e72.png |      RAW_FIGURE |
# | 40 |     8 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_bab7be0e72.png |      NRM_FIGURE |
# | 41 |     9 |                                 04_normalization/biases_10kb_446ec599e6.pickle |          BIASES |
# | 42 |     9 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |          FIGURE |
# | 43 |    10 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_dbd6039670.png |      NRM_FIGURE |
# | 44 |    11 |                                 04_normalization/biases_10kb_8fe261c68a.pickle |          BIASES |
# | 45 |    11 |       04_normalization/interactions_vs_genomic-coords.png_10000_8fe261c68a.png |          FIGURE |
# | 46 |    12 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_e89b5aa69f.png |      NRM_FIGURE |
# | 47 |    13 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_c8e49087d1.png |      NRM_FIGURE |
# | 48 |    14 |                                 04_normalization/biases_10kb_20256baab7.pickle |          BIASES |
# | 49 |    14 |       04_normalization/interactions_vs_genomic-coords.png_10000_20256baab7.png |          FIGURE |
# | 50 |    14 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# '----^-------^--------------------------------------------------------------------------------^-----------------'
# ,------.
# | JOBs |
# ,----.-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                      Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                  skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                   skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                   skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                   skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                     type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                             force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                               reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:ICE factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 21:50:33 | 15/11/2022 21:54:54 | Normalize |     91cf12b651 |
# |  8 |     nox:0 reso:10000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[raw, norm] filter:879 only_txt:0 | 15/11/2022 21:58:41 | 15/11/2022 21:58:45 |       Bin |     bab7be0e72 |
# |  9 |                                                                                                           reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:00:46 | 15/11/2022 22:01:06 | Normalize |     446ec599e6 |
# | 10 |  nox:0 reso:10000 jobid:7 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:01:09 | 15/11/2022 22:01:10 |       Bin |     dbd6039670 |
# | 11 |                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:SQRT factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:02:56 | 15/11/2022 22:03:16 | Normalize |     8fe261c68a |
# | 12 |  nox:0 reso:10000 jobid:9 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:04:14 | 15/11/2022 22:04:16 |       Bin |     e89b5aa69f |
# | 13 | nox:0 reso:10000 jobid:11 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 15/11/2022 22:07:24 | 15/11/2022 22:07:26 |       Bin |     c8e49087d1 |
# | 14 |        reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:08:12 | 15/11/2022 22:08:50 | Normalize |     20256baab7 |
# '----^-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,----------------------.
# | INTERSECTION_OUTPUTs |
# ,----.--------.--------------------.-----------------------.------------------------.---------------------.---------------------.
# | Id | PATHid | Total_interactions | Multiple_interactions | Median_fragment_length | MAD_fragment_length | Max_fragment_length |
# |----+--------+--------------------+-----------------------+------------------------+---------------------+---------------------|
# |  1 |     22 |         33,026,529 |   2:793590 3:2649 4:4 |                    144 |                  55 |                 624 |
# '----^--------^--------------------^-----------------------^------------------------^---------------------^---------------------'
# ,---------------.
# | MAPPED_INPUTs |
# ,----.--------.-------------.------.------.------.--------.---------------.-------------------.----------.-----------------.---------.
# | Id | PATHid |     Entries | Trim | Frag | Read | Enzyme | Dangling_Ends |    Ligation_Sites | WRKDIRid | MAPPED_OUTPUTid | INDEXid |
# |----+--------+-------------+------+------+------+--------+---------------+-------------------+----------+-----------------+---------|
# |  1 |      2 | 363,126,824 | None | full |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               5 |       3 |
# |  2 |      2 | 336,797,085 | None | frag |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               6 |       3 |
# |  3 |      7 | 307,207,567 | None | full |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |               9 |       3 |
# |  4 |      7 | 284,470,795 | None | frag |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |              10 |       3 |
# |  5 |     11 | 307,207,567 | None | full |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              13 |       3 |
# |  6 |     11 | 284,907,570 | None | frag |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              14 |       3 |
# |  7 |     15 | 363,126,824 | None | full |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              17 |       3 |
# |  8 |     15 | 337,015,337 | None | frag |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              18 |       3 |
# '----^--------^-------------^------^------^------^--------^---------------^-------------------^----------^-----------------^---------'
# ,----------------.
# | MAPPED_OUTPUTs |
# ,----.--------.-------.-----------------.
# | Id | PATHid | BEDid | Uniquely_mapped |
# |----+--------+-------+-----------------|
# |  1 |      6 |    19 |       6,487,780 |
# |  2 |      5 |    19 |      26,329,739 |
# |  3 |     10 |    19 |       4,095,047 |
# |  4 |      9 |    19 |      22,736,772 |
# |  5 |     14 |    21 |       4,327,299 |
# |  6 |     13 |    21 |      22,299,997 |
# |  7 |     18 |    21 |       6,473,705 |
# |  8 |     17 |    21 |      26,111,487 |
# '----^--------^-------^-----------------'
# ,----------------.
# | PARSED_OUTPUTs |
# ,----.--------.-----------------------.----------------.
# | Id | PATHid | Total_uniquely_mapped |      Multiples |
# |----+--------+-----------------------+----------------|
# |  1 |     19 |            59,649,338 | 1:1195164,2:60 |
# |  2 |     21 |            59,212,488 | 1:1212999,2:68 |
# '----^--------^-----------------------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  1 |     7 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.155025 |     10,000 |           ICE |      1 |
# |  2 |     9 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.163011 |     10,000 |       Vanilla |      1 |
# |  3 |    11 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.152085 |     10,000 |          SQRT |      1 |
# |  4 |    14 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.144083 |     10,000 |          oneD |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm norm \
#     --jobid 13

# %% [markdown]
# oneD normalized matrix 50kb

# %%
Image(filename='../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_0c74b80961.png')

# %% [markdown]
# ### Other normalizations

# %% [markdown]
# ICE and Vanilla normalizations are widely used however other, more convoluted, normalizations <a name="ref-4"/>[(Hu et al., 2012)](#cite-hu2012hicnorm) <a name="ref-5"/>[(Yaffe and Tanay, 2011)](#cite-Yaffe2011) can be used outside TADbit and then loaded in TADbit as normalized matrices for further analysis.

# %% [markdown]
# ### Best normalization

# %% [markdown]
# Which is the best normalization to use is a question that can not be answered easily because it depends on the type of data and the type of analysis.
#
# Most of the time Hi-C experiments are conducted in different conditions and, for each, in several replicates. A good way to find the best normalization method may be to select the one that achieve to minimize the differences between replicates and maximize the differences between conditions (this in the context of the analysis to be performed).

# %% [markdown]
# <!--bibtex
# @article{hu2012hicnorm,
#   title={HiCNorm: removing biases in Hi-C data via Poisson regression},
#   author={Hu, Ming and Deng, Ke and Selvaraj, Siddarth and Qin, Zhaohui and Ren, Bing and Liu, Jun S},
#   journal={Bioinformatics},
#   volume={28},
#   number={23},
#   pages={3131--3133},
#   year={2012},
#   publisher={Oxford Univ Press}
# }
# @article{Yaffe2011,
# abstract = {Hi-C experiments measure the probability of physical proximity between pairs of chromosomal loci on a genomic scale. We report on several systematic biases that substantially affect the Hi-C experimental procedure, including the distance between restriction sites, the GC content of trimmed ligation junctions and sequence uniqueness. To address these biases, we introduce an integrated probabilistic background model and develop algorithms to estimate its parameters and renormalize Hi-C data. Analysis of corrected human lymphoblast contact maps provides genome-wide evidence for interchromosomal aggregation of active chromatin marks, including DNase-hypersensitive sites and transcriptionally active foci. We observe extensive long-range (up to 400 kb) cis interactions at active promoters and derive asymmetric contact profiles next to transcription start sites and CTCF binding sites. Clusters of interacting chromosomal domains suggest physical separation of centromere-proximal and centromere-distal regions. These results provide a computational basis for the inference of chromosomal architectures from Hi-C experiments.},
# author = {Yaffe, Eitan and Tanay, Amos},
# doi = {10.1038/ng.947},
# file = {:home/fransua/.local/share/data/Mendeley Ltd./Mendeley Desktop/Downloaded/Yaffe, Tanay - 2011 - Probabilistic modeling of Hi-C contact maps eliminates systematic biases to characterize global chromosomal archit.pdf:pdf},
# issn = {1546-1718},
# journal = {Nature genetics},
# keywords = {Binding Sites,Chromosomes,Cluster Analysis,Epigenesis,Genetic,Human,Humans,Lymphocytes,Lymphocytes: ultrastructure,Models,Probability},
# mendeley-groups = {Research articles},
# month = {nov},
# number = {11},
# pages = {1059--65},
# pmid = {22001755},
# title = {{Probabilistic modeling of Hi-C contact maps eliminates systematic biases to characterize global chromosomal architecture.}},
# url = {http://www.ncbi.nlm.nih.gov/pubmed/22001755},
# volume = {43},
# year = {2011}
# }
# @article{Imakaev2012a,
# abstract = {Extracting biologically meaningful information from chromosomal interactions obtained with genome-wide chromosome conformation capture (3C) analyses requires the elimination of systematic biases. We present a computational pipeline that integrates a strategy to map sequencing reads with a data-driven method for iterative correction of biases, yielding genome-wide maps of relative contact probabilities. We validate this ICE (iterative correction and eigenvector decomposition) technique on published data obtained by the high-throughput 3C method Hi-C, and we demonstrate that eigenvector decomposition of the obtained maps provides insights into local chromatin states, global patterns of chromosomal interactions, and the conserved organization of human and mouse chromosomes.},
# author = {Imakaev, Maxim V and Fudenberg, Geoffrey and McCord, Rachel Patton and Naumova, Natalia and Goloborodko, Anton and Lajoie, Bryan R and Dekker, Job and Mirny, Leonid A},
# doi = {10.1038/nmeth.2148},
# file = {:home/fransua/.local/share/data/Mendeley Ltd./Mendeley Desktop/Downloaded/Imakaev et al. - 2012 - Iterative correction of Hi-C data reveals hallmarks of chromosome organization.pdf:pdf},
# issn = {1548-7105},
# journal = {Nature methods},
# keywords = {Hi-C},
# mendeley-groups = {stats/Hi-C,Research articles},
# mendeley-tags = {Hi-C},
# month = {oct},
# number = {10},
# pages = {999--1003},
# pmid = {22941365},
# title = {{Iterative correction of Hi-C data reveals hallmarks of chromosome organization.}},
# url = {http://www.ncbi.nlm.nih.gov/pubmed/22941365},
# volume = {9},
# year = {2012}
# }
# @article{Rao2014,
# author = {Rao, Suhas S P and Huntley, Miriam H and Durand, Neva C and Stamenova, Elena K and Bochkov, Ivan D. and {James T. Robinson} and Sanborn, Adrian L. and Machol, Ido and Omer, Arina D. and Lander, Eric S. and Lieberman-Aiden, Erez},
# doi = {10.1016/j.cell.2014.11.021},
# file = {:home/fransua/.local/share/data/Mendeley Ltd./Mendeley Desktop/Downloaded/Rao et al. - 2014 - A 3D Map of the Human Genome at Kilobase Resolution Reveals Principles of Chromatin Looping.pdf:pdf},
# issn = {0092-8674},
# journal = {Cell},
# keywords = {Hi-C},
# mendeley-groups = {Research articles,projects/GEVO/CTCF},
# mendeley-tags = {Hi-C},
# number = {7},
# pages = {1665--1680},
# pmid = {25497547},
# publisher = {Elsevier Inc.},
# title = {{A 3D Map of the Human Genome at Kilobase Resolution Reveals Principles of Chromatin Looping}},
# url = {http://dx.doi.org/10.1016/j.cell.2014.11.021},
# volume = {159},
# year = {2014}
# }
#
# -->

# %% [markdown]
# ### References
#
# <a name="cite-Imakaev2012a"/><sup>[^](#ref-1) </sup>Imakaev, Maxim V and Fudenberg, Geoffrey and McCord, Rachel Patton and Naumova, Natalia and Goloborodko, Anton and Lajoie, Bryan R and Dekker, Job and Mirny, Leonid A. 2012. _Iterative correction of Hi-C data reveals hallmarks of chromosome organization._. [URL](http://www.ncbi.nlm.nih.gov/pubmed/22941365)
#
# <a name="cite-Rao2014"/><sup>[^](#ref-2) </sup>Rao, Suhas S P and Huntley, Miriam H and Durand, Neva C and Stamenova, Elena K and Bochkov, Ivan D. and James T. Robinson and Sanborn, Adrian L. and Machol, Ido and Omer, Arina D. and Lander, Eric S. and Lieberman-Aiden, Erez. 2014. _A 3D Map of the Human Genome at Kilobase Resolution Reveals Principles of Chromatin Looping_. [URL](http://dx.doi.org/10.1016/j.cell.2014.11.021)
#
# <a name="cite-Vidal2018"/><sup>[^](#ref-3) </sup>Enrique Vidal, François le Dily, Javier Quilez, Ralph Stadhouders, Yasmina Cuartero, Thomas Graf, Marc A Marti-Renom, Miguel Beato, Guillaume J Filion. 2018. _OneD: increasing reproducibility of Hi-C samples with abnormal karyotypes_. [URL](https://doi.org/10.1093/nar/gky064)
#
# <a name="cite-hu2012hicnorm"/><sup>[^](#ref-4) </sup>Hu, Ming and Deng, Ke and Selvaraj, Siddarth and Qin, Zhaohui and Ren, Bing and Liu, Jun S. 2012. _HiCNorm: removing biases in Hi-C data via Poisson regression_.
#
# <a name="cite-Yaffe2011"/><sup>[^](#ref-5) </sup>Yaffe, Eitan and Tanay, Amos. 2011. _Probabilistic modeling of Hi-C contact maps eliminates systematic biases to characterize global chromosomal architecture._. [URL](http://www.ncbi.nlm.nih.gov/pubmed/22001755)
