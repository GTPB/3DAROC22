# %% [markdown]
# ## Model parameters optimisation

# %% [markdown]
# __running time__: < 50 min
#
# The Hi-C data used in these notebooks comes from the manuscript <a name="ref-1"/>[(Stadhouders R, Vidal E, Serra F, Di Stefano B et al. 2018)](#cite-ralph) where Hi-C experiment where conducted in different states during highly-efficient somatic cell reprogramming of somatic cells into pluripotent stem cells (PSCs) by the transcription factors (TFs) OCT4, SOX2, KLF4 and MYC.
#
# We are going to generate three-dimensional (3D) models at 10kbp of the region chr3:33950000-35450000 which contains the SOX2 locus in the first (B cells) and last stage (PSC cells) of the reprogramming.
#
# The input data for the modelling will be normalized and filtered Hi-C matrix. We already normalized the data in previous notebooks:

# %%
# %%bash
#
# tadbit describe -w ../results/PSC_rep1/ -t 8 -W Resolution,10000
# Out:
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  4 |    16 |    23 |    15,975 |        348 |        879 |         102.157286 |               100.0 |        -1.163238 |     10,000 |       Vanilla |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %%
# %%bash
#
# tadbit normalize -w ../results/PSC_rep1 -r 10000
# Out:
#   - Parsing BAM (101 chunks)                                                   [2022-11-16 10:09:57]
#       -> cis interactions are defined as being bellow 1 Mb
#       -> trans interactions are defined as being bellow 5 Mb
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Collecting cis and total interactions per bin (101 chunks)                 [2022-11-16 10:10:03]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .
#   - Removing columns with too few or too much interactions                     [2022-11-16 10:10:04]
#       -> too few interactions defined as less than        40 interactions
#       -> removed 348 columns of 15975 (2.2%)
#   - Rescaling sum of interactions per bins                                     [2022-11-16 10:10:04]
#   - Vanilla normalization                                                      [2022-11-16 10:10:04]
#   - Getting sum of normalized bins                                             [2022-11-16 10:10:04]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing Cis percentage                                                   [2022-11-16 10:10:07]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#     * Cis-percentage: 100.0%
#   - Rescaling decay                                                            [2022-11-16 10:10:10]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing interaction decay vs genomic distance                            [2022-11-16 10:10:15]
#     -> Decay slope 0.7-10 Mb	-1.1632380327535754
#   - Saving biases and badcol columns                                           [2022-11-16 10:10:15]
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |         SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 46 |    12 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 47 |    12 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 48 |    12 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 49 |    13 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_f948fa28e7.png |      NRM_FIGURE |
# | 50 |    14 |                        05_sub-matrices/raw_chr3:200-1400_25kb_e75e5a6176.mcool |      RAW_MATRIX |
# | 51 |    14 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_e75e5a6176.mcool |      NRM_MATRIX |
# | 52 |    15 |                         05_sub-matrices/norm_chr3:200-1400_25kb_4f6e350c4c.mat |      NRM_MATRIX |
# | 53 |    16 |                                 04_normalization/biases_10kb_5d9acdba25.pickle |          BIASES |
# | 54 |    16 |       04_normalization/interactions_vs_genomic-coords.png_10000_5d9acdba25.png |          FIGURE |
# '----^-------^--------------------------------------------------------------------------------^-----------------'
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                        Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                    skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                       type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                               force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                            reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:24:57 | 15/11/2022 22:25:06 | Normalize |     dd4e283c12 |
# |  8 |                                                 nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:32:27 | 15/11/2022 22:32:47 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                             reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:54:42 | 15/11/2022 22:54:51 | Normalize |     a39af1233b |
# | 10 |                                                                                      nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:54:53 | 15/11/2022 23:01:14 |   Segment |     78ca8c83b1 |
# | 11 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 23:02:16 | 15/11/2022 23:02:17 |       Bin |     917a355190 |
# | 12 |          reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:27:15 | 16/11/2022 09:27:32 | Normalize |     3adcaa6638 |
# | 13 |    nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:28:33 | 16/11/2022 09:28:45 |       Bin |     f948fa28e7 |
# | 14 | nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:29:39 | 16/11/2022 09:29:42 |       Bin |     e75e5a6176 |
# | 15 | nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:54 | 16/11/2022 09:40:58 |       Bin |     4f6e350c4c |
# | 16 |                                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 ratio_limit:1.0 cistrans_filter:1 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:09:57 | 16/11/2022 10:10:15 | Normalize |     5d9acdba25 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,----------------------.
# | INTERSECTION_OUTPUTs |
# ,----.--------.--------------------.-----------------------.------------------------.---------------------.---------------------.
# | Id | PATHid | Total_interactions | Multiple_interactions | Median_fragment_length | MAD_fragment_length | Max_fragment_length |
# |----+--------+--------------------+-----------------------+------------------------+---------------------+---------------------|
# |  1 |     22 |         33,026,529 |   2:793590 3:2649 4:4 |                    144 |                  55 |                 624 |
# '----^--------^--------------------^-----------------------^------------------------^---------------------^---------------------'
# ,---------------.
# | MAPPED_INPUTs |
# ,----.--------.-------------.------.------.------.--------.---------------.-------------------.----------.-----------------.---------.
# | Id | PATHid |     Entries | Trim | Frag | Read | Enzyme | Dangling_Ends |    Ligation_Sites | WRKDIRid | MAPPED_OUTPUTid | INDEXid |
# |----+--------+-------------+------+------+------+--------+---------------+-------------------+----------+-----------------+---------|
# |  1 |      2 | 363,126,824 | None | full |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               5 |       3 |
# |  2 |      2 | 336,797,085 | None | frag |    1 |   MboI |   MboI:1.661% | MboI-MboI:33.943% |        1 |               6 |       3 |
# |  3 |      7 | 307,207,567 | None | full |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |               9 |       3 |
# |  4 |      7 | 284,470,795 | None | frag |    1 |   MboI |   MboI:3.723% | MboI-MboI:26.161% |        1 |              10 |       3 |
# |  5 |     11 | 307,207,567 | None | full |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              13 |       3 |
# |  6 |     11 | 284,907,570 | None | frag |    2 |   MboI |   MboI:3.531% | MboI-MboI:27.311% |        1 |              14 |       3 |
# |  7 |     15 | 363,126,824 | None | full |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              17 |       3 |
# |  8 |     15 | 337,015,337 | None | frag |    2 |   MboI |   MboI:1.745% | MboI-MboI:34.115% |        1 |              18 |       3 |
# '----^--------^-------------^------^------^------^--------^---------------^-------------------^----------^-----------------^---------'
# ,----------------.
# | MAPPED_OUTPUTs |
# ,----.--------.-------.-----------------.
# | Id | PATHid | BEDid | Uniquely_mapped |
# |----+--------+-------+-----------------|
# |  1 |      6 |    19 |       6,487,780 |
# |  2 |      5 |    19 |      26,329,739 |
# |  3 |     10 |    19 |       4,095,047 |
# |  4 |      9 |    19 |      22,736,772 |
# |  5 |     14 |    21 |       4,327,299 |
# |  6 |     13 |    21 |      22,299,997 |
# |  7 |     18 |    21 |       6,473,705 |
# |  8 |     17 |    21 |      26,111,487 |
# '----^--------^-------^-----------------'
# ,----------------.
# | PARSED_OUTPUTs |
# ,----.--------.-----------------------.----------------.
# | Id | PATHid | Total_uniquely_mapped |      Multiples |
# |----+--------+-----------------------+----------------|
# |  1 |     19 |            59,649,338 | 1:1195164,2:60 |
# |  2 |     21 |            59,212,488 | 1:1212999,2:68 |
# '----^--------^-----------------------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     46,300 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,238,103 |    True |     6 |
# |  3 |     29 |              error |    570,419 |    True |     6 |
# |  4 |     30 | extra dangling-end |  6,039,326 |    True |     6 |
# |  5 |     31 | too close from RES |  6,912,438 |   False |     6 |
# |  6 |     32 |          too short |  1,057,291 |    True |     6 |
# |  7 |     33 |          too large |      2,170 |    True |     6 |
# |  8 |     34 |   over-represented |    445,743 |   False |     6 |
# |  9 |     35 |         duplicated |    733,709 |    True |     6 |
# | 10 |     36 |      random breaks |     75,840 |    True |     6 |
# | 11 |     22 |        valid-pairs | 22,272,405 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  1 |     7 |    23 |     1,598 |         31 |        879 |         102.018229 |               100.0 |        -1.151699 |    100,000 |       Vanilla |      1 |
# |  2 |     9 |    23 |     3,195 |         64 |        879 |         102.020202 |               100.0 |        -1.156116 |     50,000 |       Vanilla |      1 |
# |  3 |    12 |    23 |     6,390 |        133 |        879 |          102.05513 |               100.0 |        -1.143915 |     25,000 |          oneD |      1 |
# |  4 |    16 |    23 |    15,975 |        348 |        879 |         102.157286 |               100.0 |        -1.163238 |     10,000 |       Vanilla |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %% [markdown]
# To plot the input matrix we use `tadbit bin`. To pass to tadbit which normalization we want to use for the matrix we pass the `jobid` of the normalization job. In our cas we are going to use the Vanilla normalization:

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm norm \
#     --jobid 16 \
#     --triangular
# Out:
# Extraction of chr3:33950000-35450000
# Getting norm matrices                                                          [2022-11-16 10:11:16]
#
#   (Matrix size 150x150)                                                        [2022-11-16 10:11:16]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-16 10:11:16]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-16 10:11:16]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: norm                                                              [2022-11-16 10:11:17]
# Cleaning                                                                       [2022-11-16 10:11:17]
# Saving to DB                                                                   [2022-11-16 10:11:17]
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                        Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                    skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                       type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                               force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                            reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:24:57 | 15/11/2022 22:25:06 | Normalize |     dd4e283c12 |
# |  8 |                                                 nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:32:27 | 15/11/2022 22:32:47 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                             reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:54:42 | 15/11/2022 22:54:51 | Normalize |     a39af1233b |
# | 10 |                                                                                      nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:54:53 | 15/11/2022 23:01:14 |   Segment |     78ca8c83b1 |
# | 11 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 23:02:16 | 15/11/2022 23:02:17 |       Bin |     917a355190 |
# | 12 |          reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:27:15 | 16/11/2022 09:27:32 | Normalize |     3adcaa6638 |
# | 13 |    nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:28:33 | 16/11/2022 09:28:45 |       Bin |     f948fa28e7 |
# | 14 | nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:29:39 | 16/11/2022 09:29:42 |       Bin |     e75e5a6176 |
# | 15 | nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:54 | 16/11/2022 09:40:58 |       Bin |     4f6e350c4c |
# | 16 |                                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 ratio_limit:1.0 cistrans_filter:1 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:09:57 | 16/11/2022 10:10:15 | Normalize |     5d9acdba25 |
# | 17 |   nox:0 reso:10000 jobid:16 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 10:11:16 | 16/11/2022 10:11:17 |       Bin |     b47e22c268 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |         SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 46 |    12 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 47 |    12 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 48 |    12 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 49 |    13 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_f948fa28e7.png |      NRM_FIGURE |
# | 50 |    14 |                        05_sub-matrices/raw_chr3:200-1400_25kb_e75e5a6176.mcool |      RAW_MATRIX |
# | 51 |    14 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_e75e5a6176.mcool |      NRM_MATRIX |
# | 52 |    15 |                         05_sub-matrices/norm_chr3:200-1400_25kb_4f6e350c4c.mat |      NRM_MATRIX |
# | 53 |    16 |                                 04_normalization/biases_10kb_5d9acdba25.pickle |          BIASES |
# | 54 |    16 |       04_normalization/interactions_vs_genomic-coords.png_10000_5d9acdba25.png |          FIGURE |
# | 55 |    17 |                     05_sub-matrices/nrm_chr3:3395-3545_10kb_b47e22c268_tri.png |      NRM_FIGURE |
# '----^-------^--------------------------------------------------------------------------------^-----------------'

# %% [markdown]
# Vanilla normalized matrix 10kb

# %%
from IPython.display import Image
Image(filename='../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_b47e22c268_tri.png')

# %% [markdown]
# Now we create the Hi-C normalized matrix in text format with `tadbit bin` and the `--only_txt` flag

# %%
# %%bash
#
# tadbit bin -w ../results/PSC_rep1/ --only_txt \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --norm norm \
#     --jobid 16
# Out:
# Extraction of chr3:33950000-35450000
# Getting and writing matrices                                                   [2022-11-16 10:12:13]
#
#   (Matrix size 150x150)                                                        [2022-11-16 10:12:13]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-16 10:12:13]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Writing matrices                                                           [2022-11-16 10:12:13]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
# Cleaning                                                                       [2022-11-16 10:12:14]
# Saving to DB                                                                   [2022-11-16 10:12:14]
# ,------.
# | JOBs |
# ,----.----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                         Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 08:11:58 | 15/11/2022 12:34:38 |       Map |     41c1c36f14 |
# |  2 |                                                                                                                      skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 09:44:51 | 15/11/2022 16:53:13 |       Map |     a9f0be07b7 |
# |  3 |                                                                                                                      skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 10:18:05 | 15/11/2022 17:43:17 |       Map |     0e153acfb1 |
# |  4 |                                                                                                                      skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 15/11/2022 12:35:53 | 15/11/2022 18:41:52 |       Map |     36f3830796 |
# |  5 |                                                                                                                                                        type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 20:27:55 | 15/11/2022 20:44:05 |     Parse |     956d70d051 |
# |  6 |                                force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 20:44:33 | 15/11/2022 20:54:23 |    Filter |     f69652928b |
# |  7 |                                                                                                             reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:24:57 | 15/11/2022 22:25:06 | Normalize |     dd4e283c12 |
# |  8 |                                                  nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:32:27 | 15/11/2022 22:32:47 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                              reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:54:42 | 15/11/2022 22:54:51 | Normalize |     a39af1233b |
# | 10 |                                                                                       nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:54:53 | 15/11/2022 23:01:14 |   Segment |     78ca8c83b1 |
# | 11 |   nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 23:02:16 | 15/11/2022 23:02:17 |       Bin |     917a355190 |
# | 12 |           reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:27:15 | 16/11/2022 09:27:32 | Normalize |     3adcaa6638 |
# | 13 |     nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:28:33 | 16/11/2022 09:28:45 |       Bin |     f948fa28e7 |
# | 14 |  nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:29:39 | 16/11/2022 09:29:42 |       Bin |     e75e5a6176 |
# | 15 |  nox:0 reso:25000 jobid:12 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:54 | 16/11/2022 09:40:58 |       Bin |     4f6e350c4c |
# | 16 |                                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 ratio_limit:1.0 cistrans_filter:1 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:09:57 | 16/11/2022 10:10:15 | Normalize |     5d9acdba25 |
# | 17 |    nox:0 reso:10000 jobid:16 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 10:11:16 | 16/11/2022 10:11:17 |       Bin |     b47e22c268 |
# | 18 | nox:0 reso:10000 jobid:16 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 10:12:13 | 16/11/2022 10:12:14 |       Bin |     9cc09aece7 |
# '----^----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                       /scratch/results/test_data/3DAROC22/results_new/PSC_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344971_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344971_1.fastq.gz_MboI_41c1c36f14.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344971_1_full_1-end_41c1c36f14.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344971_1_frag_1-end_41c1c36f14.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344972_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344972_1.fastq.gz_MboI_a9f0be07b7.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344972_1_full_1-end_a9f0be07b7.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344972_1_frag_1-end_a9f0be07b7.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344972_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344972_2.fastq.gz_MboI_0e153acfb1.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344972_2_full_1-end_0e153acfb1.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344972_2_frag_1-end_0e153acfb1.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344971_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344971_2.fastq.gz_MboI_36f3830796.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344971_2_full_1-end_36f3830796.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344971_2_frag_1-end_36f3830796.map |         SAM/MAP |
# | 19 |     5 |                                     02_parsed_reads/PSC_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                     02_parsed_reads/PSC_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 46 |    12 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 47 |    12 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 48 |    12 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 49 |    13 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_f948fa28e7.png |      NRM_FIGURE |
# | 50 |    14 |                        05_sub-matrices/raw_chr3:200-1400_25kb_e75e5a6176.mcool |      RAW_MATRIX |
# | 51 |    14 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_e75e5a6176.mcool |      NRM_MATRIX |
# | 52 |    15 |                         05_sub-matrices/norm_chr3:200-1400_25kb_4f6e350c4c.mat |      NRM_MATRIX |
# | 53 |    16 |                                 04_normalization/biases_10kb_5d9acdba25.pickle |          BIASES |
# | 54 |    16 |       04_normalization/interactions_vs_genomic-coords.png_10000_5d9acdba25.png |          FIGURE |
# | 55 |    17 |                     05_sub-matrices/nrm_chr3:3395-3545_10kb_b47e22c268_tri.png |      NRM_FIGURE |
# | 56 |    18 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_9cc09aece7.abc |      NRM_MATRIX |
# '----^-------^--------------------------------------------------------------------------------^-----------------'

# %%
# %%bash
#
# head ../results/PSC_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_9cc09aece7.abc
# Out:
# # CRM chr3	159745316
# # chr3:3395-3545 resolution:10000
# # MASKED
# 0	52		35.92399852435043
# 0	2		327.02290938567666
# 0	24		55.903572101319895
# 0	30		69.39231116826463
# 0	71		19.898484328112637
# 0	1		561.631952088835
# 0	3		191.77819421133987

# %% [markdown]
# ### Data Transformation and scoring function
#
# This  step is automatically done in TADbit.
# A a weight is generated for each pair of interactions proportional to their interaction count as in formula:
#
# $$weight(I, J) = \frac{\sum^N_{i=0}{\sum^N_{j=0}{(matrix(i, j))}}}{\sum^N_{i=0}{(matrix(i, J))} \times \sum^N_{j=0}{(matrix(I, j))}}$$
#
# The raw data are then multiplied by this weight. In the case that multiple experiments are used, the weighted interaction values are normalised using a factor  (default set as 1) in order to compare between experiments.
# Then, a Z-score of the off-diagonal normalised/weighted interaction is calculated as in formula:
#
# $$zscore(I, J) = \frac{log_{10}(weight(I, J) \times matrix(I, J)) - mean(log_{10}(weight \times matrix))}{stddev(log_{10}(weight \times matrix))}$$
#
# The Z-scores are then transformed to distance restraints. To define the type of restraints  between  each  pair  of  particles. we need to identified  empirically  three  optimal  parameters  (i) a maximal  distance  between  two  non-interacting  particles (maxdist), (ii) a lower-bound  cutoff  to  define  particles  that  do  not  interact  frequently (lowfreq) and (iii) an  upper-bound  cutoff  to  define  particles  that  do  interact  frequently (upfreq). In TADbit this is done via a grid  search  approach.
#
#
# The following picture shows the different component of the scoring funtion that is optimised during the Monte Carlo  simulated annealing sampling protocol.
# Two  consecutive particles are spatially restrained  by  a  harmonic  oscillator  with  an  equilibrium  distance  that  corresponds to  the sum of their radii. Non-consecutive  particles  with  contact  frequencies  above  the  upper-bound  cutoff are restrained by a harmonic  oscillator  at  an  equilibrium  distance,  while  those  below  the  lower-bound  cutoff are maintained further than  an  equilibrium  distance  by  a  lower  bound  harmonic  oscillator.
#
# ![](images/tadbit_restraints.png)

# %% [markdown]
# ### Optimization of parameters

# %% [markdown]
# We need to identified empirically (via a grid-search optimisation) the optimal parameters for the mdoelling procedure:
#
#  - maxdist: maximal distance assosiated two interacting particles.
#  - upfreq: to define particles that do interact frequently (defines attraction)
#  - lowfreq: to define particles that do not interact frequently ( defines repulsion)
#  - dcutoff: the definition of "contact" in units of bead diameter. Value of 2 means that a contact will occur when 2
#     beads are closer than 2 times their diameter. This will be used to compare 3D models with Hi-C interaction maps.
#
#
# Pairs of beads interacting less than lowfreq (left dashed line) are penalized if they are closer than their assigned minimum distance (Harmonic lower bound).
# Pairs of beads interacting more than ufreq (right dashed line) are penalized if they are further apart than their assigned maximum distance (Harmonic upper bound).
# Pairs of beads which interaction fall in between lowfreq and upfreq are not penalized except if they are neighbours (Harmonic)
#
#
# ![](images/tadbit_distance_freq_fitting.png)

# %% [markdown]
# In the parameter optimization step we are going to give a set of ranges for the different search parameters. For each possible combination TADbit will produce a set of models.
#
# In each individual model we consider that two beads are in contact if their distance in 3D space is lower than the specified distance cutoff. TADbit builds a cumulative contact map for each set of models as shown in the schema below. The contact map is then compared with the Hi-C interaction experiment by means of a Spearman correlation coefficient. The sets having higher correlation coefficients are those that best represents the original data.
#
# ![](images/Contact_map.png)

# %% [markdown]
# The optimization is conducted by the `tadbit model` with the `--optimize` flag. To pass to tadbit which matrix we want to use we pass the `jobid` of the previously generated text matrix. The following optimization takes around 20 minutes with 8 cpus:

# %%
# %%bash
#
# tadbit model -w ../results/PSC_rep1/ \
#     --reso 10000 \
#     --crm chr3 \
#     --beg 33950000 --end 35450000 \
#     --maxdist 250:250:100 \
#     --upfreq=0.4:0.8:0.2 \
#     --lowfreq=-1.0:-0.6:0.2 \
#     --dcutoff 2:4:1 \
#     --scale 0.01 \
#     --nmodels 200 --nkeep 100 \
#     --cpu 8 \
#     --jobid 18 \
#     --optimize
# Out:
#      o Loading Hi-C matrix
#
#         Optimization
#         ***********
#
#           - Region: Chromosome chr3 from 33950000 to 35450000 at resolution 10 kb (150 particles)
#
#      o Optimizing parameters
#
# Optimizing parameters...
#
#
# #  Optimization UpFreq LowFreq MaxDist  scale  cutoff | Correlation
#
#        1/3         0.4      -1     250   0.01     2.0 | 0.8193
#        2/3         0.4      -1     250   0.01     3.0 | 0.7872
#        3/3         0.4      -1     250   0.01     4.0 | 0.6241
#        1/3         0.4    -0.8     250   0.01     2.0 | 0.8182
#        2/3         0.4    -0.8     250   0.01     3.0 | 0.7843
#        3/3         0.4    -0.8     250   0.01     4.0 | 0.6269
#        1/3         0.4    -0.6     250   0.01     2.0 | 0.8201
#        2/3         0.4    -0.6     250   0.01     3.0 | 0.7876
#        3/3         0.4    -0.6     250   0.01     4.0 | 0.6269
#        1/3         0.6      -1     250   0.01     2.0 | 0.8096
#        2/3         0.6      -1     250   0.01     3.0 | 0.7955
#        3/3         0.6      -1     250   0.01     4.0 | 0.6864
#        1/3         0.6    -0.8     250   0.01     2.0 | 0.8108
#        2/3         0.6    -0.8     250   0.01     3.0 | 0.7959
#        3/3         0.6    -0.8     250   0.01     4.0 | 0.6864
#        1/3         0.6    -0.6     250   0.01     2.0 | 0.8103
#        2/3         0.6    -0.6     250   0.01     3.0 | 0.7957
#        3/3         0.6    -0.6     250   0.01     4.0 | 0.6884
#        1/3         0.8      -1     250   0.01     2.0 | 0.7967
#        2/3         0.8      -1     250   0.01     3.0 | 0.8001
#        3/3         0.8      -1     250   0.01     4.0 | 0.7399
#        1/3         0.8    -0.8     250   0.01     2.0 | 0.7972
#        2/3         0.8    -0.8     250   0.01     3.0 | 0.8007
#        3/3         0.8    -0.8     250   0.01     4.0 | 0.7410
#        1/3         0.8    -0.6     250   0.01     2.0 | 0.7971
#        2/3         0.8    -0.6     250   0.01     3.0 | 0.8014
#        3/3         0.8    -0.6     250   0.01     4.0 | 0.7408
#
# Best combination:
#      =>        0.4    -0.6     250   0.01      2 0.8201
#
#
#  optimization done

# %% [markdown]
# Results are stored in the `07_model/<id>` subfolder. They include the generated ensemble of models of the grid in a format that can be loaded in the python TADbit library and the correlation grid search plot.

# %%
# %%bash
#
# tadbit describe -w ../results/PSC_rep1/ -t 13
# Out:
# ,-----------------.
# | MODELED_REGIONs |
# ,----.-------.-------.--------.------------.--------.-------.-------.
# | Id | JOBid |  Type | PATHid |  PARAM_md5 |   RESO |   BEG |   END |
# |----+-------+-------+--------+------------+--------+-------+-------|
# |  1 |    19 | OPTIM |     57 | 486617218f | 10,000 | 3,395 | 3,545 |
# '----^-------^-------^--------^------------^--------^-------^-------'

# %%
# %%bash
#
# ls -lart ../results/PSC_rep1/07_model/486617218f_chr3_3396-3545/
# Out:
# total 1088
# drwxrwxr-x  3 dcastillo dcastillo   4096 Nov 16 10:13 ..
# -rw-rw-r--  1 dcastillo dcastillo 936907 Nov 16 10:13 _tmp_common_data.pickle
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:15 cfg_250_0.4_-1_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:17 cfg_250_0.4_-0.8_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:19 cfg_250_0.4_-0.6_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:21 cfg_250_0.6_-1_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:23 cfg_250_0.6_-0.8_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:26 cfg_250_0.6_-0.6_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:27 cfg_250_0.8_-1_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:29 cfg_250_0.8_-0.8_0.01
# drwxrwxr-x  2 dcastillo dcastillo  16384 Nov 16 10:31 cfg_250_0.8_-0.6_0.01
# drwxrwxr-x 11 dcastillo dcastillo   4096 Nov 16 10:31 .
# -rw-rw-r--  1 dcastillo dcastillo  16598 Nov 16 10:31 optimal_params_DVfDdYIAfQ.pdf

# %%
from IPython.display import IFrame

IFrame("../results/PSC_rep1/07_model/486617218f_chr3_3396-3545/optimal_params_DVfDdYIAfQ.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="../results/PSC_rep1/07_model/486617218f_chr3_3396-3545/optimal_params_DVfDdYIAfQ.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# In reality our search space will be much larger than our example. Here is the grid plot that was produced after approximately 12 hours with 32 cpus:
#
# ![optimal parameters](images/optimal_parameters.png)

# %% [markdown]
# ### B cell
#
# We follow the same steps shown in the PSC cell for the B cell.

# %%
# %%bash
#
# tadbit normalize -w ../results/B_rep1/ \
#     --normalization Vanilla \
#     -r 10000 \
#     --min_count 100
# Out:
#   - Parsing BAM (101 chunks)                                                   [2022-11-16 10:57:01]
#       -> cis interactions are defined as being bellow 1 Mb
#       -> trans interactions are defined as being bellow 5 Mb
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Collecting cis and total interactions per bin (101 chunks)                 [2022-11-16 10:57:06]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .
#   - Removing columns with too few or too much interactions                     [2022-11-16 10:57:07]
#       -> too few interactions defined as less than       100 interactions
#       -> removed 346 columns (330/346 null/high counts) of 15975 (2.2%)
#   - Rescaling sum of interactions per bins                                     [2022-11-16 10:57:07]
#   - Vanilla normalization                                                      [2022-11-16 10:57:07]
#   - Getting sum of normalized bins                                             [2022-11-16 10:57:07]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing Cis percentage                                                   [2022-11-16 10:57:10]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#     * Cis-percentage: 100.0%
#   - Rescaling decay                                                            [2022-11-16 10:57:13]
#      .......... .......... .......... .......... ..........     50/101
#      .......... .......... .......... .......... ..........    100/101
#      .                                                         101/101
#
#   - Computing interaction decay vs genomic distance                            [2022-11-16 10:57:18]
#     -> Decay slope 0.7-10 Mb	-1.0401656255872516
#   - Saving biases and badcol columns                                           [2022-11-16 10:57:18]
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                         /scratch/results/test_data/3DAROC22/results_new/B_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344924_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344924_1.fastq.gz_MboI_5b3316b80e.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344924_1_full_1-end_5b3316b80e.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344924_1_frag_1-end_5b3316b80e.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344923_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344923_1.fastq.gz_MboI_4d9078d574.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344923_1_full_1-end_4d9078d574.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344923_1_frag_1-end_4d9078d574.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344923_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344923_2.fastq.gz_MboI_1f3d25b69d.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344923_2_full_1-end_1f3d25b69d.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344923_2_frag_1-end_1f3d25b69d.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344924_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344924_2.fastq.gz_MboI_f771732f99.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344924_2_full_1-end_f771732f99.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344924_2_frag_1-end_f771732f99.map |         SAM/MAP |
# | 19 |     5 |                                       02_parsed_reads/B_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                       02_parsed_reads/B_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_c3b1dd2168_tri.png |      RAW_FIGURE |
# | 46 |    12 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 47 |    13 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 48 |    13 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 49 |    13 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 50 |    14 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_93de449286.png |      NRM_FIGURE |
# | 51 |    15 |                        05_sub-matrices/raw_chr3:200-1400_25kb_6a37ed4539.mcool |      RAW_MATRIX |
# | 52 |    15 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_6a37ed4539.mcool |      NRM_MATRIX |
# | 53 |    16 |                         05_sub-matrices/norm_chr3:200-1400_25kb_82f0c035ae.mat |      NRM_MATRIX |
# | 54 |    17 |                                 04_normalization/biases_10kb_446ec599e6.pickle |          BIASES |
# | 55 |    17 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |          FIGURE |
# '----^-------^--------------------------------------------------------------------------------^-----------------'
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                        Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:50:58 | 14/11/2022 18:30:39 |       Map |     5b3316b80e |
# |  2 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:45:33 | 14/11/2022 18:34:24 |       Map |     4d9078d574 |
# |  3 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:44:26 | 15/11/2022 03:27:43 |       Map |     1f3d25b69d |
# |  4 |                                                                                                                    skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:42:54 | 15/11/2022 03:30:14 |       Map |     f771732f99 |
# |  5 |                                                                                                                                                       type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 08:10:22 | 15/11/2022 08:28:43 |     Parse |     956d70d051 |
# |  6 |                               force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 09:42:58 | 15/11/2022 09:56:21 |    Filter |     f69652928b |
# |  7 |                                                                                                            reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:35:55 | 15/11/2022 22:36:02 | Normalize |     dd4e283c12 |
# |  8 |                                                 nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:36:22 | 15/11/2022 22:36:41 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                             reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:41:20 | 15/11/2022 22:41:29 | Normalize |     a39af1233b |
# | 10 |                                                                                      nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:41:31 | 15/11/2022 22:47:41 |   Segment |     78ca8c83b1 |
# | 11 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:44 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:51:23 | 15/11/2022 22:51:25 |       Bin |     c3b1dd2168 |
# | 12 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:54:08 | 15/11/2022 22:54:10 |       Bin |     917a355190 |
# | 13 |          reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:24:36 | 16/11/2022 09:25:03 | Normalize |     3adcaa6638 |
# | 14 |    nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:25:54 | 16/11/2022 09:26:07 |       Bin |     93de449286 |
# | 15 | nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:26:53 | 16/11/2022 09:26:57 |       Bin |     6a37ed4539 |
# | 16 | nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:26 | 16/11/2022 09:40:31 |       Bin |     82f0c035ae |
# | 17 |                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:57:01 | 16/11/2022 10:57:19 | Normalize |     446ec599e6 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     44,924 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,208,310 |    True |     6 |
# |  3 |     29 |              error |    324,646 |    True |     6 |
# |  4 |     30 | extra dangling-end |  4,531,164 |    True |     6 |
# |  5 |     31 | too close from RES |  5,108,666 |   False |     6 |
# |  6 |     32 |          too short |    729,669 |    True |     6 |
# |  7 |     33 |          too large |      6,835 |    True |     6 |
# |  8 |     34 |   over-represented |    377,402 |   False |     6 |
# |  9 |     35 |         duplicated |    538,175 |    True |     6 |
# | 10 |     36 |      random breaks |    136,118 |    True |     6 |
# | 11 |     22 |        valid-pairs | 16,840,861 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,----------------------.
# | INTERSECTION_OUTPUTs |
# ,----.--------.--------------------.-----------------------.------------------------.---------------------.---------------------.
# | Id | PATHid | Total_interactions | Multiple_interactions | Median_fragment_length | MAD_fragment_length | Max_fragment_length |
# |----+--------+--------------------+-----------------------+------------------------+---------------------+---------------------|
# |  1 |     22 |         25,594,740 |       2:402281 3:1117 |                    174 |                  71 |                 712 |
# '----^--------^--------------------^-----------------------^------------------------^---------------------^---------------------'
# ,---------------.
# | MAPPED_INPUTs |
# ,----.--------.-------------.------.------.------.--------.---------------.-------------------.----------.-----------------.---------.
# | Id | PATHid |     Entries | Trim | Frag | Read | Enzyme | Dangling_Ends |    Ligation_Sites | WRKDIRid | MAPPED_OUTPUTid | INDEXid |
# |----+--------+-------------+------+------+------+--------+---------------+-------------------+----------+-----------------+---------|
# |  1 |      2 | 327,058,737 | None | full |    1 |   MboI |   MboI:3.100% | MboI-MboI:22.184% |        1 |               5 |       3 |
# |  2 |      2 | 302,842,665 | None | frag |    1 |   MboI |   MboI:3.100% | MboI-MboI:22.184% |        1 |               6 |       3 |
# |  3 |      7 | 332,989,091 | None | full |    1 |   MboI |   MboI:3.765% | MboI-MboI:21.108% |        1 |               9 |       3 |
# |  4 |      7 | 308,212,256 | None | frag |    1 |   MboI |   MboI:3.765% | MboI-MboI:21.108% |        1 |              10 |       3 |
# |  5 |     11 | 332,989,091 | None | full |    2 |   MboI |   MboI:3.731% | MboI-MboI:21.622% |        1 |              13 |       3 |
# |  6 |     11 | 308,992,073 | None | frag |    2 |   MboI |   MboI:3.731% | MboI-MboI:21.622% |        1 |              14 |       3 |
# |  7 |     15 | 327,058,737 | None | full |    2 |   MboI |   MboI:3.131% | MboI-MboI:23.199% |        1 |              17 |       3 |
# |  8 |     15 | 303,291,382 | None | frag |    2 |   MboI |   MboI:3.131% | MboI-MboI:23.199% |        1 |              18 |       3 |
# '----^--------^-------------^------^------^------^--------^---------------^-------------------^----------^-----------------^---------'
# ,----------------.
# | MAPPED_OUTPUTs |
# ,----.--------.-------.-----------------.
# | Id | PATHid | BEDid | Uniquely_mapped |
# |----+--------+-------+-----------------|
# |  1 |      6 |    19 |       3,886,608 |
# |  2 |      5 |    19 |      24,216,072 |
# |  3 |     10 |    19 |       3,729,744 |
# |  4 |      9 |    19 |      24,776,835 |
# |  5 |     14 |    21 |       1,273,746 |
# |  6 |     13 |    21 |      23,997,018 |
# |  7 |     18 |    21 |       4,072,769 |
# |  8 |     17 |    21 |      23,767,355 |
# '----^--------^-------^-----------------'
# ,----------------.
# | PARSED_OUTPUTs |
# ,----.--------.-----------------------.---------------.
# | Id | PATHid | Total_uniquely_mapped |     Multiples |
# |----+--------+-----------------------+---------------|
# |  1 |     19 |            56,609,259 | 1:732312,2:86 |
# |  2 |     21 |            53,110,888 | 1:516399,2:61 |
# '----^--------^-----------------------^---------------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.---------.-------.
# | Id | PATHid |               Name |      Count | Applied | JOBid |
# |----+--------+--------------------+------------+---------+-------|
# |  1 |     27 |        self-circle |     44,924 |    True |     6 |
# |  2 |     28 |       dangling-end |  3,208,310 |    True |     6 |
# |  3 |     29 |              error |    324,646 |    True |     6 |
# |  4 |     30 | extra dangling-end |  4,531,164 |    True |     6 |
# |  5 |     31 | too close from RES |  5,108,666 |   False |     6 |
# |  6 |     32 |          too short |    729,669 |    True |     6 |
# |  7 |     33 |          too large |      6,835 |    True |     6 |
# |  8 |     34 |   over-represented |    377,402 |   False |     6 |
# |  9 |     35 |         duplicated |    538,175 |    True |     6 |
# | 10 |     36 |      random breaks |    136,118 |    True |     6 |
# | 11 |     22 |        valid-pairs | 16,840,861 |         |     6 |
# '----^--------^--------------------^------------^---------^-------'
# ,-------------------.
# | NORMALIZE_OUTPUTs |
# ,----.-------.-------.-----------.------------.------------.--------------------.---------------------.------------------.------------.---------------.--------.
# | Id | JOBid | Input | N_columns | N_filtered | BAM_filter | Cis_percentage_Raw | Cis_percentage_Norm | Slope_700kb_10Mb | Resolution | Normalization | Factor |
# |----+-------+-------+-----------+------------+------------+--------------------+---------------------+------------------+------------+---------------+--------|
# |  1 |     7 |    23 |     1,598 |         31 |        879 |         102.018229 |               100.0 |        -1.036893 |    100,000 |       Vanilla |      1 |
# |  2 |     9 |    23 |     3,195 |         64 |        879 |         102.020202 |               100.0 |        -1.037237 |     50,000 |       Vanilla |      1 |
# |  3 |    13 |    23 |     6,390 |        133 |        879 |         102.071778 |               100.0 |        -1.030706 |     25,000 |          oneD |      1 |
# |  4 |    17 |    23 |    15,975 |        346 |        879 |         102.157004 |               100.0 |        -1.040166 |     10,000 |       Vanilla |      1 |
# '----^-------^-------^-----------^------------^------------^--------------------^---------------------^------------------^------------^---------------^--------'

# %%
# %%bash
#
# tadbit bin -w ../results/B_rep1/ --only_plot \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --cmap Reds --format png \
#     --norm norm \
#     --jobid 17 \
#     --triangular
# Out:
# Extraction of chr3:33950000-35450000
# Getting norm matrices                                                          [2022-11-16 10:58:15]
#
#   (Matrix size 150x150)                                                        [2022-11-16 10:58:15]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-16 10:58:15]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Getting matrices                                                           [2022-11-16 10:58:15]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#  - Plotting: norm                                                              [2022-11-16 10:58:16]
# Cleaning                                                                       [2022-11-16 10:58:17]
# Saving to DB                                                                   [2022-11-16 10:58:17]
# ,------.
# | JOBs |
# ,----.---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                        Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:50:58 | 14/11/2022 18:30:39 |       Map |     5b3316b80e |
# |  2 |                                                                                                                     skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:45:33 | 14/11/2022 18:34:24 |       Map |     4d9078d574 |
# |  3 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:44:26 | 15/11/2022 03:27:43 |       Map |     1f3d25b69d |
# |  4 |                                                                                                                    skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:42:54 | 15/11/2022 03:30:14 |       Map |     f771732f99 |
# |  5 |                                                                                                                                                       type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 08:10:22 | 15/11/2022 08:28:43 |     Parse |     956d70d051 |
# |  6 |                               force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 09:42:58 | 15/11/2022 09:56:21 |    Filter |     f69652928b |
# |  7 |                                                                                                            reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:35:55 | 15/11/2022 22:36:02 | Normalize |     dd4e283c12 |
# |  8 |                                                 nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:36:22 | 15/11/2022 22:36:41 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                             reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:41:20 | 15/11/2022 22:41:29 | Normalize |     a39af1233b |
# | 10 |                                                                                      nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:41:31 | 15/11/2022 22:47:41 |   Segment |     78ca8c83b1 |
# | 11 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:44 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:51:23 | 15/11/2022 22:51:25 |       Bin |     c3b1dd2168 |
# | 12 |  nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:54:08 | 15/11/2022 22:54:10 |       Bin |     917a355190 |
# | 13 |          reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:24:36 | 16/11/2022 09:25:03 | Normalize |     3adcaa6638 |
# | 14 |    nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:25:54 | 16/11/2022 09:26:07 |       Bin |     93de449286 |
# | 15 | nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:26:53 | 16/11/2022 09:26:57 |       Bin |     6a37ed4539 |
# | 16 | nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:26 | 16/11/2022 09:40:31 |       Bin |     82f0c035ae |
# | 17 |                                                                                                             reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:57:01 | 16/11/2022 10:57:19 | Normalize |     446ec599e6 |
# | 18 |   nox:0 reso:10000 jobid:17 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 10:58:15 | 16/11/2022 10:58:17 |       Bin |     ef2379a427 |
# '----^---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                         /scratch/results/test_data/3DAROC22/results_new/B_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344924_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344924_1.fastq.gz_MboI_5b3316b80e.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344924_1_full_1-end_5b3316b80e.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344924_1_frag_1-end_5b3316b80e.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344923_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344923_1.fastq.gz_MboI_4d9078d574.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344923_1_full_1-end_4d9078d574.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344923_1_frag_1-end_4d9078d574.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344923_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344923_2.fastq.gz_MboI_1f3d25b69d.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344923_2_full_1-end_1f3d25b69d.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344923_2_frag_1-end_1f3d25b69d.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344924_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344924_2.fastq.gz_MboI_f771732f99.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344924_2_full_1-end_f771732f99.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344924_2_frag_1-end_f771732f99.map |         SAM/MAP |
# | 19 |     5 |                                       02_parsed_reads/B_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                       02_parsed_reads/B_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_c3b1dd2168_tri.png |      RAW_FIGURE |
# | 46 |    12 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 47 |    13 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 48 |    13 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 49 |    13 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 50 |    14 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_93de449286.png |      NRM_FIGURE |
# | 51 |    15 |                        05_sub-matrices/raw_chr3:200-1400_25kb_6a37ed4539.mcool |      RAW_MATRIX |
# | 52 |    15 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_6a37ed4539.mcool |      NRM_MATRIX |
# | 53 |    16 |                         05_sub-matrices/norm_chr3:200-1400_25kb_82f0c035ae.mat |      NRM_MATRIX |
# | 54 |    17 |                                 04_normalization/biases_10kb_446ec599e6.pickle |          BIASES |
# | 55 |    17 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |          FIGURE |
# | 56 |    18 |                     05_sub-matrices/nrm_chr3:3395-3545_10kb_ef2379a427_tri.png |      NRM_FIGURE |
# '----^-------^--------------------------------------------------------------------------------^-----------------'

# %% [markdown]
# Vanilla normalized matrix 10kb

# %%
Image(filename='../results/B_rep1/05_sub-matrices/nrm_chr3:3395-3545_10kb_ef2379a427_tri.png')

# %%
# %%bash
#
# tadbit bin -w ../results/B_rep1/ --only_txt \
#     -c chr3:33950000-35450000 --resolution 10000  \
#     --norm norm \
#     --jobid 17
# Out:
# Extraction of chr3:33950000-35450000
# Getting and writing matrices                                                   [2022-11-16 10:59:32]
#
#   (Matrix size 150x150)                                                        [2022-11-16 10:59:32]
#
#   - Parsing BAM (75 chunks)                                                    [2022-11-16 10:59:32]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
#   - Writing matrices                                                           [2022-11-16 10:59:32]
#      .......... .......... .......... .......... ..........      50/75
#      .......... .......... .....                                 75/75
#
# Cleaning                                                                       [2022-11-16 10:59:33]
# Saving to DB                                                                   [2022-11-16 10:59:33]
# ,------.
# | JOBs |
# ,----.----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-----------.----------------.
# | Id |                                                                                                                                                                                                                                                                                         Parameters |         Launch_time |         Finish_time |      Type | Parameters_md5 |
# |----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-----------+----------------|
# |  1 |                                                                                                                      skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:50:58 | 14/11/2022 18:30:39 |       Map |     5b3316b80e |
# |  2 |                                                                                                                      skip_mapping:0 read:1 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 13:45:33 | 14/11/2022 18:34:24 |       Map |     4d9078d574 |
# |  3 |                                                                                                                      skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:8 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:44:26 | 15/11/2022 03:27:43 |       Map |     1f3d25b69d |
# |  4 |                                                                                                                     skip_mapping:0 read:2 chr_name:[] noX:0 fast_fragment:0 cpus:16 mapper:gem mapper_binary:/home/dcastillo/miniconda2/envs/3DAROC22/bin/gem-mapper mapper_param:{} gem_version:3 | 14/11/2022 20:42:54 | 15/11/2022 03:30:14 |       Map |     f771732f99 |
# |  5 |                                                                                                                                                        type:map filter_chrom:^(chr)?[A-Za-z]?[0-9]{0,3}[XVI]{0,3}(?:ito)?[A-Z-a-z]?(_dna)?$ compress_input:0 genome:[refGenome/mm39_chr3.fa] noX:0 | 15/11/2022 08:10:22 | 15/11/2022 08:28:43 |     Parse |     956d70d051 |
# |  6 |                                force:0 resume:0 apply:[1, 2, 3, 4, 6, 7, 9, 10] cpus:32 noX:0 over_represented:0.001 strict_duplicates:0 max_frag_size:100000 min_frag_size:50 re_proximity:5 mad:0 max_f:0 median:0 compress_input:0 format:mid valid:0 clean:0 samtools:samtools fast_fragment:0 | 15/11/2022 09:42:58 | 15/11/2022 09:56:21 |    Filter |     f69652928b |
# |  7 |                                                                                                             reso:100000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:35:55 | 15/11/2022 22:36:02 | Normalize |     dd4e283c12 |
# |  8 |                                                  nosql:0 all_bins:0 reso:100000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 rich_in_A:../refGenome/mm39_chr3.fa savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:1 only_tads:0 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:36:22 | 15/11/2022 22:36:41 |   Segment |     d7d3e585c9 |
# |  9 |                                                                                                              reso:50000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 15/11/2022 22:41:20 | 15/11/2022 22:41:29 | Normalize |     a39af1233b |
# | 10 |                                                                                       nosql:0 all_bins:0 reso:50000 filter:[1, 2, 3, 4, 6, 7, 9, 10] noX:0 savecorr:0 fix_corr_scale:0 format:png n_evs:3 smoothing_window:0 only_compartments:0 only_tads:1 verbose:0 crms:[chr3] cpus:12 force:0 | 15/11/2022 22:41:31 | 15/11/2022 22:47:41 |   Segment |     78ca8c83b1 |
# | 11 |   nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:44 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:51:23 | 15/11/2022 22:51:25 |       Bin |     c3b1dd2168 |
# | 12 |   nox:0 reso:50000 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 tad_def:10 coord1:chr3:35000000-41000000 normalizations:[raw] filter:879 only_txt:0 | 15/11/2022 22:54:08 | 15/11/2022 22:54:10 |       Bin |     917a355190 |
# | 13 |           reso:25000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:oneD mappability:../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph fasta:../refGenome/mm39_chr3.fa factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 09:24:36 | 16/11/2022 09:25:03 | Normalize |     3adcaa6638 |
# | 14 |     nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:0 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:25:54 | 16/11/2022 09:26:07 |       Bin |     93de449286 |
# | 15 |  nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:0 cooler:1 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 09:26:53 | 16/11/2022 09:26:57 |       Bin |     6a37ed4539 |
# | 16 |  nox:0 reso:25000 jobid:13 force:0 nchunks:100 cpus:32 matrix:1 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:5000000-35000000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 09:40:26 | 16/11/2022 09:40:31 |       Bin |     82f0c035ae |
# | 17 |                                                                                                              reso:10000 max_njobs:100 cpus:32 normalize_only:0 noX:0 normalization:Vanilla factor:1 seed:1 min_count:100.0 ratio_limit:1.0 cistrans_filter:0 filter_only:0 filter:879 only_valid:0 | 16/11/2022 10:57:01 | 16/11/2022 10:57:19 | Normalize |     446ec599e6 |
# | 18 |    nox:0 reso:10000 jobid:17 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:1 force_plot:0 only_plot:1 interactive:0 triangular:1 xtick_rotation:-25 cmap:Reds bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:0 | 16/11/2022 10:58:15 | 16/11/2022 10:58:17 |       Bin |     ef2379a427 |
# | 19 | nox:0 reso:10000 jobid:17 force:0 nchunks:100 cpus:32 matrix:0 cooler:0 row_names:0 plot:0 force_plot:0 only_plot:0 interactive:0 triangular:0 xtick_rotation:-25 cmap:viridis bad_color:white format:png transform:log2 coord1:chr3:33950000-35450000 normalizations:[norm] filter:879 only_txt:1 | 16/11/2022 10:59:32 | 16/11/2022 10:59:33 |       Bin |     2d79f75489 |
# '----^----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-----------^----------------'
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-----------------.
# | Id | JOBid |                                                                           Path |            Type |
# |----+-------+--------------------------------------------------------------------------------+-----------------|
# |  1 |     1 |                         /scratch/results/test_data/3DAROC22/results_new/B_rep1 |         WORKDIR |
# |  2 |     1 |                                                    ../../SRR5344924_1.fastq.gz |    MAPPED_FASTQ |
# |  3 |     1 |                                                  ../../refGenome/mm39_chr3.gem |           INDEX |
# |  4 |     1 |                                      SRR5344924_1.fastq.gz_MboI_5b3316b80e.png |          FIGURE |
# |  5 |     1 |                            01_mapped_r1/SRR5344924_1_full_1-end_5b3316b80e.map |         SAM/MAP |
# |  6 |     1 |                            01_mapped_r1/SRR5344924_1_frag_1-end_5b3316b80e.map |         SAM/MAP |
# |  7 |     2 |                                                    ../../SRR5344923_1.fastq.gz |    MAPPED_FASTQ |
# |  8 |     2 |                                      SRR5344923_1.fastq.gz_MboI_4d9078d574.png |          FIGURE |
# |  9 |     2 |                            01_mapped_r1/SRR5344923_1_full_1-end_4d9078d574.map |         SAM/MAP |
# | 10 |     2 |                            01_mapped_r1/SRR5344923_1_frag_1-end_4d9078d574.map |         SAM/MAP |
# | 11 |     3 |                                                    ../../SRR5344923_2.fastq.gz |    MAPPED_FASTQ |
# | 12 |     3 |                                      SRR5344923_2.fastq.gz_MboI_1f3d25b69d.png |          FIGURE |
# | 13 |     3 |                            01_mapped_r2/SRR5344923_2_full_1-end_1f3d25b69d.map |         SAM/MAP |
# | 14 |     3 |                            01_mapped_r2/SRR5344923_2_frag_1-end_1f3d25b69d.map |         SAM/MAP |
# | 15 |     4 |                                                    ../../SRR5344924_2.fastq.gz |    MAPPED_FASTQ |
# | 16 |     4 |                                      SRR5344924_2.fastq.gz_MboI_f771732f99.png |          FIGURE |
# | 17 |     4 |                            01_mapped_r2/SRR5344924_2_full_1-end_f771732f99.map |         SAM/MAP |
# | 18 |     4 |                            01_mapped_r2/SRR5344924_2_frag_1-end_f771732f99.map |         SAM/MAP |
# | 19 |     5 |                                       02_parsed_reads/B_rep1_r1_956d70d051.tsv |             BED |
# | 20 |     5 |                                                   ../../refGenome/mm39_chr3.fa |           FASTA |
# | 21 |     5 |                                       02_parsed_reads/B_rep1_r2_956d70d051.tsv |             BED |
# | 22 |     6 |                      03_filtered_reads/valid_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 23 |     6 |                                  03_filtered_reads/intersection_f69652928b.bam |         HIC_BAM |
# | 24 |     6 |                              03_filtered_reads/intersection_f69652928b.bam.bai |         HIC_BAI |
# | 25 |     6 |                        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv |          2D_BED |
# | 26 |     6 |                                        histogram_fragment_sizes_f69652928b.pdf |          FIGURE |
# | 27 |     6 |        03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_self-circle.tsv |          FILTER |
# | 28 |     6 |       03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_dangling-end.tsv |          FILTER |
# | 29 |     6 |              03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_error.tsv |          FILTER |
# | 30 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_extra_dangling-end.tsv |          FILTER |
# | 31 |     6 | 03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_close_from_RES.tsv |          FILTER |
# | 32 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_short.tsv |          FILTER |
# | 33 |     6 |          03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_too_large.tsv |          FILTER |
# | 34 |     6 |   03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_over-represented.tsv |          FILTER |
# | 35 |     6 |         03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_duplicated.tsv |          FILTER |
# | 36 |     6 |      03_filtered_reads/all_r1-r2_intersection_f69652928b.tsv_random_breaks.tsv |          FILTER |
# | 37 |     7 |                                04_normalization/biases_100kb_dd4e283c12.pickle |          BIASES |
# | 38 |     7 |      04_normalization/interactions_vs_genomic-coords.png_100000_dd4e283c12.png |          FIGURE |
# | 39 |     8 |                         06_segmentation/compartments_100kb/chr3_d7d3e585c9.tsv |     COMPARTMENT |
# | 40 |     8 |                06_segmentation/compartments_100kb/chr3_EigVect1_d7d3e585c9.tsv |     COMPARTMENT |
# | 41 |     8 |                     06_segmentation/compartments_100kb/chr3_EV1_d7d3e585c9.png |          FIGURE |
# | 42 |     9 |                                 04_normalization/biases_50kb_a39af1233b.pickle |          BIASES |
# | 43 |     9 |       04_normalization/interactions_vs_genomic-coords.png_50000_a39af1233b.png |          FIGURE |
# | 44 |    10 |                                  06_segmentation/tads_50kb/chr3_78ca8c83b1.tsv |             TAD |
# | 45 |    11 |                       05_sub-matrices/raw_chr3:700-820_50kb_c3b1dd2168_tri.png |      RAW_FIGURE |
# | 46 |    12 |                       05_sub-matrices/raw_chr3:700-820_50kb_917a355190_tri.png |      RAW_FIGURE |
# | 47 |    13 |                                 04_normalization/biases_25kb_3adcaa6638.pickle |          BIASES |
# | 48 |    13 |       04_normalization/interactions_vs_genomic-coords.png_25000_3adcaa6638.png |          FIGURE |
# | 49 |    13 |                   ../../refGenome/genmap/mappability/mm39_chr3.genmap.bedgraph | EXT_MAPPABILITY |
# | 50 |    14 |                          05_sub-matrices/nrm_chr3:200-1400_25kb_93de449286.png |      NRM_FIGURE |
# | 51 |    15 |                        05_sub-matrices/raw_chr3:200-1400_25kb_6a37ed4539.mcool |      RAW_MATRIX |
# | 52 |    15 |                        05_sub-matrices/nrm_chr3:200-1400_25kb_6a37ed4539.mcool |      NRM_MATRIX |
# | 53 |    16 |                         05_sub-matrices/norm_chr3:200-1400_25kb_82f0c035ae.mat |      NRM_MATRIX |
# | 54 |    17 |                                 04_normalization/biases_10kb_446ec599e6.pickle |          BIASES |
# | 55 |    17 |       04_normalization/interactions_vs_genomic-coords.png_10000_446ec599e6.png |          FIGURE |
# | 56 |    18 |                     05_sub-matrices/nrm_chr3:3395-3545_10kb_ef2379a427_tri.png |      NRM_FIGURE |
# | 57 |    19 |                         05_sub-matrices/nrm_chr3:3395-3545_10kb_2d79f75489.abc |      NRM_MATRIX |
# '----^-------^--------------------------------------------------------------------------------^-----------------'

# %%
# %%bash
#
# tadbit model -w ../results/B_rep1/ \
#     --reso 10000 \
#     --crm chr3 \
#     --beg 33950000 --end 35450000 \
#     --maxdist 175 \
#     --upfreq=-0.8:-0.2:0.2 \
#     --lowfreq=-1.4:-1.0:0.2 \
#     --dcutoff 2:4:1 \
#     --scale 0.01 \
#     --nmodels 200 --nkeep 100 \
#     --cpu 16 \
#     --jobid 19 \
#     --optimize
# Out:
#      o Loading Hi-C matrix
#
#         Optimization
#         ***********
#
#           - Region: Chromosome chr3 from 33950000 to 35450000 at resolution 10 kb (150 particles)
#
#      o Optimizing parameters
#
# Optimizing parameters...
#
#
# #  Optimization UpFreq LowFreq MaxDist  scale  cutoff | Correlation
#
#        1/3        -0.8    -1.4     175   0.01     2.0 | 0.6388
#        2/3        -0.8    -1.4     175   0.01     3.0 | 0.1365
# /home/dcastillo/miniconda2/envs/3DAROC22/lib/python3.7/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#        3/3        -0.8    -1.4     175   0.01     4.0 | nan
#        1/3        -0.8    -1.2     175   0.01     2.0 | 0.6216
#        2/3        -0.8    -1.2     175   0.01     3.0 | 0.1478
#        3/3        -0.8    -1.2     175   0.01     4.0 | nan
#        1/3        -0.8      -1     175   0.01     2.0 | 0.6222
#        2/3        -0.8      -1     175   0.01     3.0 | 0.1470
#        3/3        -0.8      -1     175   0.01     4.0 | nan
#        1/3        -0.6    -1.4     175   0.01     2.0 | 0.6452
#        2/3        -0.6    -1.4     175   0.01     3.0 | 0.2085
#        3/3        -0.6    -1.4     175   0.01     4.0 | nan
#        1/3        -0.6    -1.2     175   0.01     2.0 | 0.6291
#        2/3        -0.6    -1.2     175   0.01     3.0 | 0.2146
#        3/3        -0.6    -1.2     175   0.01     4.0 | nan
#        1/3        -0.6      -1     175   0.01     2.0 | 0.6368
#        2/3        -0.6      -1     175   0.01     3.0 | 0.2143
#        3/3        -0.6      -1     175   0.01     4.0 | nan
#        1/3        -0.4    -1.4     175   0.01     2.0 | 0.6634
#        2/3        -0.4    -1.4     175   0.01     3.0 | 0.2952
#        3/3        -0.4    -1.4     175   0.01     4.0 | nan
#        1/3        -0.4    -1.2     175   0.01     2.0 | 0.6525
#        2/3        -0.4    -1.2     175   0.01     3.0 | 0.3020
#        3/3        -0.4    -1.2     175   0.01     4.0 | nan
#        1/3        -0.4      -1     175   0.01     2.0 | 0.6586
#        2/3        -0.4      -1     175   0.01     3.0 | 0.3121
#        3/3        -0.4      -1     175   0.01     4.0 | nan
#        1/3        -0.2    -1.4     175   0.01     2.0 | 0.6716
#        2/3        -0.2    -1.4     175   0.01     3.0 | 0.3736
#        3/3        -0.2    -1.4     175   0.01     4.0 | 0.0222
#        1/3        -0.2    -1.2     175   0.01     2.0 | 0.6679
#        2/3        -0.2    -1.2     175   0.01     3.0 | 0.3831
#        3/3        -0.2    -1.2     175   0.01     4.0 | 0.0193
#        1/3        -0.2      -1     175   0.01     2.0 | 0.6654
#        2/3        -0.2      -1     175   0.01     3.0 | 0.3849
#        3/3        -0.2      -1     175   0.01     4.0 | 0.0254
#
# Best combination:
#      =>       -0.2    -1.4     175   0.01      2 0.6716
#
#
#  optimization done

# %%
from IPython.display import IFrame

IFrame("../results/B_rep1/07_model/032bcd0451_chr3_3396-3545/optimal_params_JPWuQaRFkM.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="../results/B_rep1/07_model/032bcd0451_chr3_3396-3545/optimal_params_JPWuQaRFkM.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
