# %% [markdown]
# ## Comparison of Hi-C experiments

# %% [markdown]
# __running time__: < 5 min
#
# ### Comparison between cell types

# %% [markdown]
# The `tadbit merge` tool is used to combine two working environments together. It is usually intended for the merging of biological replicas in order to increase the resolution of the Hi-C matrices.
# Optionally, the tool provides relevant measures to compare the experiments to be merged at a given resolution.
#
# We are going to use `tadbit merge` with the `--skip_merge` flag to compare the experiments:

# %%
# %%bash
#
# tadbit merge -w ../results/compare_PSC_B \
#     -w1 ../results/PSC_rep1/ \
#     -w2 ../results/B_rep1/ \
#     --skip_merge \
#     -r 100000 \
#     --norm
# Out:
# ../results/PSC_rep1/trace.db
# ../results/B_rep1/trace.db
#   - loading first sample ../results/PSC_rep1/03_filtered_reads/intersection_f69652928b.bam[2022-11-15 23:04:45]
#
#   (Matrix size 1598x1598)                                                      [2022-11-15 23:04:45]
#
#   - Parsing BAM (100 chunks)                                                   [2022-11-15 23:04:45]
#      .......... .......... .......... .......... ..........     50/100
#      .......... .......... .......... .......... ..........    100/100
#
#   - Getting matrices                                                           [2022-11-15 23:04:49]
#      .......... .......... .......... .......... ..........     50/100
#      .......... .......... .......... .......... ..........    100/100
#
#   - loading second sample ../results/B_rep1/03_filtered_reads/intersection_f69652928b.bam[2022-11-15 23:04:54]
#
#   (Matrix size 1598x1598)                                                      [2022-11-15 23:04:54]
#
#   - Parsing BAM (100 chunks)                                                   [2022-11-15 23:04:54]
#      .......... .......... .......... .......... ..........     50/100
#      .......... .......... .......... .......... ..........    100/100
#
#   - Getting matrices                                                           [2022-11-15 23:04:57]
#      .......... .......... .......... .......... ..........     50/100
#      .......... .......... .......... .......... ..........    100/100
#
#   - comparing experiments                                                      [2022-11-15 23:05:02]
#     => correlation between equidistant loci                                    [2022-11-15 23:05:02]
#          - correlation score (SCC): 0.5892 (+- 0.0126266)
#     => correlation between eigenvectors                                        [2022-11-15 23:05:03]
#     => reproducibility score                                                   [2022-11-15 23:05:19]
#          - reproducibility score: 0.2378
# ,-------.
# | PATHs |
# ,----.-------.--------------------------------------------------------------------------------.-------------.
# | Id | JOBid |                                                                           Path |        Type |
# |----+-------+--------------------------------------------------------------------------------+-------------|
# |  1 |     1 |                                  00_merge/decay_corr_dat_100000_65e8a7b651.txt |        CORR |
# |  2 |     1 |                                  00_merge/decay_corr_dat_100000_65e8a7b651.png |      FIGURE |
# |  3 |     1 |                                  00_merge/eigen_corr_dat_100000_65e8a7b651.txt |        CORR |
# |  4 |     1 |                                  00_merge/eigen_corr_dat_100000_65e8a7b651.png |      FIGURE |
# |  5 |     1 |                      /scratch/results/test_data/3DAROC22/results/compare_PSC_B |     WORKDIR |
# |  6 |     1 |                                                                    ../PSC_rep1 |    WORKDIR1 |
# |  7 |     1 |                                                                      ../B_rep1 |    WORKDIR2 |
# |  8 |     1 |                      ../PSC_rep1/03_filtered_reads/intersection_f69652928b.bam | EXT_HIC_BAM |
# |  9 |     1 |                        ../B_rep1/03_filtered_reads/intersection_f69652928b.bam | EXT_HIC_BAM |
# | 10 |     1 |                    ../PSC_rep1/04_normalization/biases_100kb_dd4e283c12.pickle |      BIASES |
# | 11 |     1 |                      ../B_rep1/04_normalization/biases_100kb_dd4e283c12.pickle |      BIASES |
# | 12 |     1 |        03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_self-circle.tsv |      FILTER |
# | 13 |     1 |       03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_dangling-end.tsv |      FILTER |
# | 14 |     1 |              03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_error.tsv |      FILTER |
# | 15 |     1 | 03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_extra_dangling-end.tsv |      FILTER |
# | 16 |     1 | 03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_too_close_from_RES.tsv |      FILTER |
# | 17 |     1 |          03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_too_short.tsv |      FILTER |
# | 18 |     1 |          03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_too_large.tsv |      FILTER |
# | 19 |     1 |   03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_over-represented.tsv |      FILTER |
# | 20 |     1 |         03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_duplicated.tsv |      FILTER |
# | 21 |     1 |      03_filtered_reads/all_r1-r2_intersection_65e8a7b651.tsv_random_breaks.tsv |      FILTER |
# '----^-------^--------------------------------------------------------------------------------^-------------'
# ,------.
# | JOBs |
# ,----.------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------.---------------------.---------------------.-------.----------------.
# | Id |                                                                                                                                                                                                                                                             Parameters |         Launch_time |         Finish_time |  Type | Parameters_md5 |
# |----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------+-------+----------------|
# |  1 | workdir1:../results/PSC_rep1/ workdir2:../results/B_rep1/ noX:0 cpus:32 reso:100000 skip_comparison:0 skip_merge:1 save:genome force:0 norm:1 filter:[1, 2, 3, 4, 6, 7, 9, 10] samtools:samtools tmpdb1:../results/PSC_rep1/trace.db tmpdb2:../results/B_rep1/trace.db | 15/11/2022 23:04:45 | 15/11/2022 23:05:23 | Merge |     65e8a7b651 |
# '----^------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------^---------------------^---------------------^-------^----------------'
# ,-------------.
# | MERGE_STATs |
# ,----.-------.--------.----------------.-----------------.----------.----------.----------.-----------.------------.------------.-----------.-----------.
# | Id | JOBid | Inputs |     decay_corr |      eigen_corr |   reprod |      scc |  std_scc | N_columns | N_filtered | Resolution | bias1Path | bias2Path |
# |----+-------+--------+----------------+-----------------+----------+----------+----------+-----------+------------+------------+-----------+-----------|
# |  1 |     1 |   None | .7-.5-.6-.6-.7 | .98-.86-.93-.94 | 0.237763 | 0.589241 | 0.012627 |     1,598 |         31 |    100,000 |        10 |        11 |
# '----^-------^--------^----------------^-----------------^----------^----------^----------^-----------^------------^------------^-----------^-----------'
# ,----------------.
# | FILTER_OUTPUTs |
# ,----.--------.--------------------.------------.-------.
# | Id | PATHid |               Name |      Count | JOBid |
# |----+--------+--------------------+------------+-------|
# |  1 |     -1 |        valid-pairs | 39,113,266 |     1 |
# |  2 |     12 |        self-circle |     91,224 |     1 |
# |  3 |     13 |       dangling-end |  6,446,413 |     1 |
# |  4 |     14 |              error |    895,065 |     1 |
# |  5 |     15 | extra dangling-end | 10,570,490 |     1 |
# |  6 |     16 | too close from RES | 12,021,104 |     1 |
# |  7 |     17 |          too short |  1,786,960 |     1 |
# |  8 |     18 |          too large |      9,005 |     1 |
# |  9 |     19 |   over-represented |    823,145 |     1 |
# | 10 |     20 |         duplicated |  1,271,884 |     1 |
# | 11 |     21 |      random breaks |    211,958 |     1 |
# '----^--------^--------------------^------------^-------'
#
# Done.                                                                          [2022-11-15 23:05:29]

# %% [markdown]
# Results are stored in the newly created folder `compare_PSC_B/00_merge/`. They include the spearman rank correlation of the matrix diagonals at increasing genomic distances and the correlation of the eigenvectors of the matrices.

# %%
# %%bash
#
# ls ../results/compare_PSC_B/00_merge/
# Out:
# decay_corr_dat_100000_65e8a7b651.png
# decay_corr_dat_100000_65e8a7b651.txt
# eigen_corr_dat_100000_65e8a7b651.png
# eigen_corr_dat_100000_65e8a7b651.txt

# %% [markdown]
# #### The Spearman rank correlation of the matrix diagonals

# %% [markdown]
# Spearman rank correlation of the matrix diagonals at increasing genomic distances

# %%
from IPython.display import Image
Image(filename='../results/compare_PSC_B/00_merge/decay_corr_dat_100000_65e8a7b651.png')

# %% [markdown]
# #### The correlation of the eigenvectors

# %% [markdown]
# Since the eigenvectors of a matrix capture its internal correlations, two matrices with highly correlation of eigenvectors are considered to have similar structure.
#
# In this case we limit the computation to the first 6 eigenvectors
#
# Eigenvector correlation

# %%
Image(filename='../results/compare_PSC_B/00_merge/eigen_corr_dat_100000_65e8a7b651.png')

# %% [markdown]
# __The stratum-adjusted correlation coefficient (SCC) score__
#
#
# The SCC score as in HiCrep (see https://doi.org/10.1101/gr.220640.117) is also computed. The value of SCC ranges from −1 to 1 and can be interpreted in a way similar to the standard correlation.
#
# - correlation score (SCC): 0.5892 (+- 0.0126266)

# %% [markdown]
# __The reproducibility score (Q)__
#
# Computed as in HiC-spector (https://doi.org/10.1093/bioinformatics/btx152), it is also based on comparing eigenvectors. The reproducibility score ranges from 0 (low similarity) to 1 (identity).
#
# - reproducibility score: 0.2378
